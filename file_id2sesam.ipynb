# %%
import os
import pandas as pd

# %%
r,f,d = next(os.walk("./ALTO"))

# %%
idmap = {}
for name in f:
    _,sf,_ = next(os.walk(os.path.join(r,name)))
    idmap[name] = sf[0]

# %%
import requests

# %%
def get_urn(sesamid):
    string = f"https://api.nb.no/catalog/v1/metadata/{sesamid}/struct"
    #print(string)
    res = requests.get(string)
    if res.status_code == 200:
        result = res.text
    else:
        print(res.status_code)
        result = None
    return result

# %%
import xml.etree.ElementTree as ET
from pathlib import Path
import pandas as pd

def extract_resource_info(xml_content: str) -> dict:
    """Extract URN and scan resolution from structMap XML"""
    try:
        # Parse the XML with namespace awareness
        root = ET.fromstring(xml_content)
        
        # Get the first div/resource element
        resource = root.find('.//{*}div/{*}resource')
        
        if resource is not None:
            # Extract URN base (remove page number at end)
            urn = resource.get('{http://www.w3.org/1999/xlink}href', '')
            urn_base = urn.rsplit('_', 1)[0] if urn else None
            
            info = {
                'urn_base': urn_base,
                'scan_resolution': resource.get('SCANRESOLUTION'),
                'height': resource.get('HEIGHT'),
                'width': resource.get('WIDTH')
            }
            return info
    except Exception as e:
        print(f"Error processing XML: {str(e)}")
    
    return {
        'urn_base': None,
        'scan_resolution': None,
        'height': None,
        'width': None
    }

# %%
# Example usage
def urn_base(sesamid):
    xml_content = get_urn(sesamid)
    info = extract_resource_info(xml_content)
    urn = info['urn_base']
    return urn

# %%
df_ids = pd.DataFrame.from_dict(idmap, orient='index', columns=['sesamid']).reset_index()

# %%
df_ids['urn'] = df_ids.sesamid.apply(urn_base)

# %%
df_ids['url'] = df_ids.urn.apply(lambda x: f"https://nb.no/items/{x}")

# %%
df_ids.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_870d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_870d1_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_870d1_level0_col1" class="col_heading level0 col1" >sesamid</th>
#       <th id="T_870d1_level0_col2" class="col_heading level0 col2" >urn</th>
#       <th id="T_870d1_level0_col3" class="col_heading level0 col3" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_870d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_870d1_row0_col0" class="data row0 col0" >1581443</td>
#       <td id="T_870d1_row0_col1" class="data row0 col1" >c2910cf5e44d09b996c62a1f4417fb57</td>
#       <td id="T_870d1_row0_col2" class="data row0 col2" >URN:NBN:no-nb_digimanus_279683</td>
#       <td id="T_870d1_row0_col3" class="data row0 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279683</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_870d1_row1_col0" class="data row1 col0" >1594278</td>
#       <td id="T_870d1_row1_col1" class="data row1 col1" >6b9108fc26177727be1ecf382c988b16</td>
#       <td id="T_870d1_row1_col2" class="data row1 col2" >URN:NBN:no-nb_digimanus_279883</td>
#       <td id="T_870d1_row1_col3" class="data row1 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279883</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_870d1_row2_col0" class="data row2 col0" >1579385</td>
#       <td id="T_870d1_row2_col1" class="data row2 col1" >e8ceee63c94b380060d42d52cefb26ee</td>
#       <td id="T_870d1_row2_col2" class="data row2 col2" >URN:NBN:no-nb_digimanus_279697</td>
#       <td id="T_870d1_row2_col3" class="data row2 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279697</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_870d1_row3_col0" class="data row3 col0" >1563964</td>
#       <td id="T_870d1_row3_col1" class="data row3 col1" >5f27d5b9ffdef6adf0e3a80d439f2d6c</td>
#       <td id="T_870d1_row3_col2" class="data row3 col2" >URN:NBN:no-nb_digimanus_280121</td>
#       <td id="T_870d1_row3_col3" class="data row3 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280121</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_870d1_row4_col0" class="data row4 col0" >1558161</td>
#       <td id="T_870d1_row4_col1" class="data row4 col1" >92285008828e0e5cb8eb002b7f84c421</td>
#       <td id="T_870d1_row4_col2" class="data row4 col2" >URN:NBN:no-nb_digimanus_279817</td>
#       <td id="T_870d1_row4_col3" class="data row4 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279817</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_870d1_row5_col0" class="data row5 col0" >3971423</td>
#       <td id="T_870d1_row5_col1" class="data row5 col1" >9faba46158e1c7f87ef07d235a12b0df</td>
#       <td id="T_870d1_row5_col2" class="data row5 col2" >URN:NBN:no-nb_digimanus_279923</td>
#       <td id="T_870d1_row5_col3" class="data row5 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279923</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_870d1_row6_col0" class="data row6 col0" >1587674</td>
#       <td id="T_870d1_row6_col1" class="data row6 col1" >42480c1a3c07b4adbff5438a13afa8a1</td>
#       <td id="T_870d1_row6_col2" class="data row6 col2" >URN:NBN:no-nb_digimanus_280336</td>
#       <td id="T_870d1_row6_col3" class="data row6 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280336</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_870d1_row7_col0" class="data row7 col0" >1594283</td>
#       <td id="T_870d1_row7_col1" class="data row7 col1" >136c4f5e3f4e3062f23ef71a48df293a</td>
#       <td id="T_870d1_row7_col2" class="data row7 col2" >URN:NBN:no-nb_digimanus_279749</td>
#       <td id="T_870d1_row7_col3" class="data row7 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279749</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_870d1_row8_col0" class="data row8 col0" >1594255</td>
#       <td id="T_870d1_row8_col1" class="data row8 col1" >1a64cb0fe040c09a01cf7b3c6f384705</td>
#       <td id="T_870d1_row8_col2" class="data row8 col2" >URN:NBN:no-nb_digimanus_279698</td>
#       <td id="T_870d1_row8_col3" class="data row8 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279698</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_870d1_row9_col0" class="data row9 col0" >3971323</td>
#       <td id="T_870d1_row9_col1" class="data row9 col1" >d7588fb66077bb4d852cf97d67795d64</td>
#       <td id="T_870d1_row9_col2" class="data row9 col2" >URN:NBN:no-nb_digimanus_280402</td>
#       <td id="T_870d1_row9_col3" class="data row9 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280402</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_870d1_row10_col0" class="data row10 col0" >1616602</td>
#       <td id="T_870d1_row10_col1" class="data row10 col1" >bb2668c190059b5042445443d2a57cf8</td>
#       <td id="T_870d1_row10_col2" class="data row10 col2" >URN:NBN:no-nb_digimanus_279628</td>
#       <td id="T_870d1_row10_col3" class="data row10 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279628</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_870d1_row11_col0" class="data row11 col0" >3971765</td>
#       <td id="T_870d1_row11_col1" class="data row11 col1" >b3810b756ccf27f1f8573a6d8aa80802</td>
#       <td id="T_870d1_row11_col2" class="data row11 col2" >URN:NBN:no-nb_digimanus_279730</td>
#       <td id="T_870d1_row11_col3" class="data row11 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_279730</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_870d1_row12_col0" class="data row12 col0" >1579397</td>
#       <td id="T_870d1_row12_col1" class="data row12 col1" >147773f94f5854344c23795caa972ca6</td>
#       <td id="T_870d1_row12_col2" class="data row12 col2" >URN:NBN:no-nb_digimanus_280421</td>
#       <td id="T_870d1_row12_col3" class="data row12 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280421</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_870d1_row13_col0" class="data row13 col0" >1564270</td>
#       <td id="T_870d1_row13_col1" class="data row13 col1" >35c288d57ddab3f7876058c6dbfe1371</td>
#       <td id="T_870d1_row13_col2" class="data row13 col2" >URN:NBN:no-nb_digimanus_280192</td>
#       <td id="T_870d1_row13_col3" class="data row13 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280192</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_870d1_row14_col0" class="data row14 col0" >1587758</td>
#       <td id="T_870d1_row14_col1" class="data row14 col1" >977b7d4c0f1ab3a2715c41ac1b4baf75</td>
#       <td id="T_870d1_row14_col2" class="data row14 col2" >URN:NBN:no-nb_digimanus_280751</td>
#       <td id="T_870d1_row14_col3" class="data row14 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280751</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_870d1_row15_col0" class="data row15 col0" >3971505</td>
#       <td id="T_870d1_row15_col1" class="data row15 col1" >560bc7b0cb5f7e7250951efc47819896</td>
#       <td id="T_870d1_row15_col2" class="data row15 col2" >URN:NBN:no-nb_digimanus_280003</td>
#       <td id="T_870d1_row15_col3" class="data row15 col3" >https://nb.no/items/URN:NBN:no-nb_digimanus_280003</td>
#     </tr>
#     <tr>
#       <th id="T_870d1_l

# %%
metadata = pd.read_excel("metadata.xlsx", index_col=0)

# %%
metadata['doc_id'] = metadata['filename'].apply(lambda x: x.split('_')[1])

# %%
df_metadata = metadata.merge(df_ids, left_on='doc_id', right_on='index')

# %%
df_metadata['year'] = pd.to_numeric(df_metadata['year'], errors='coerce').astype('Int64')

# %%
df_metadata["title author year acts genre doc_id sesamid urn url".split()].to_excel("metadata_links.xlsx", index=False)

# %%
characters = pd.read_excel("Karakteranalyse.xlsx", index_col = 0)

# %%
characters['doc_id']  = characters.title.apply(lambda x: x.split('_')[1])

# %%
df_characters = characters.merge(df_ids, left_on="doc_id", right_on='index')

# %%
df_characters.columns
# Out:
# Index(['title', 'name', 'gender', 'status', 'description', 'doc_id', 'index',
#        'sesamid', 'urn', 'url'],
#       dtype='object')

# %%
import urllib.parse

# %%
print("Data type of 'name' column:", df_characters['name'].dtype)
# Out:
# Data type of 'name' column: object

# %%
df_characters['search_url'] = df_characters.fillna('').apply(lambda row: f"{row['url']}?searchText=\"{urllib.parse.quote(row['name'])}\"", axis=1)

# %%
df_characters[["name","gender", "status", "doc_id", "search_url"]]
# Out:
#             name gender                status   doc_id  \
# 0         Sigrid      F                   NaN  3971483
# 1       Ragnhild      F                   NaN  3971483
# 2         Asmund      M                   NaN  3971483
# 3         Nordal      M                   NaN  3971483
# 4        Steenby      M             Studenter  3971483
# ..           ...    ...                   ...      ...
# 569        Johan      M    hans Bontignedring  1563988
# 570       Joseph      M  Falkenskjolds Tjener  1563988
# 571         Berg      M        ham en Hofmand  1563988
# 572  Præsidenten      M         i høieste Ret  1563988
# 573     En Lagna      F                   NaN  1563988
#
#                                             search_url
# 0    https://nb.no/items/URN:NBN:no-nb_digimanus_28...
# 1    https://nb.no/items/URN:NBN:no-nb_digimanus_28...
# 2    https://nb.no/items/URN:NBN:no-nb_digimanus_28...
# 3    https://nb.no/items/URN:NBN:no-nb_digimanus_28...
# 4    https://nb.no/items/URN:NBN:no-nb_digimanus_28...
# ..                                                 ...
# 569  https://nb.no/items/URN:NBN:no-nb_digimanus_27...
# 570  https://nb.no/items/URN:NBN:no-nb_digimanus_27...
# 571  https://nb.no/items/URN:NBN:no-nb_digimanus_27...
# 572  https://nb.no/items/URN:NBN:no-nb_digimanus_27...
# 573  https://nb.no/items/URN:NBN:no-nb_digimanus_27...
#
# [574 rows x 5 columns]

# %%
df_characters[["name","gender", "status", "doc_id", "search_url"]].to_excel("characters_link.xlsx", index=False)
