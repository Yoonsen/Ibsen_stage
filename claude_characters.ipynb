# %%
import anthropic
from pathlib import Path
import json
from typing import Dict, List
import logging
from time import sleep
import ast

class NorwegianPlayProcessor:
    def __init__(self, api_key: str, plays_directory: str):
        self.client = anthropic.Client(api_key=api_key)
        self.plays_dir = Path(plays_directory)
        self.setup_logging()
        
    def setup_logging(self):
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            filename='play_processing.log',
            encoding='utf-8'
        )
    
    def extract_characters_with_metadata(self, text: str, play_title: str) -> List[Dict]:
        prompt = f"""Analyze this Norwegian play from the 1800s and return ONLY a Python list of dictionaries containing character information.
        Do NOT add any explanatory text before or after the list.
        Return ONLY the list in this exact format:
        [
            {{"name": "Character Name", "gender": "M or F", "status": "social status", "description": "original description"}},
        ]

        Base gender (M/F) on:
        - Titles (Fru, Frøken, Madame = F)
        - Male titles (Herr, Hr. = M)
        - Names and professions
        - Character descriptions

        Text to analyze:
        {text}"""
        
        try:
            response = self.client.messages.create(
                model="claude-3-sonnet-20240229",
                max_tokens=1000,
                temperature=0,
                messages=[{"role": "user", "content": prompt}]
            )
            
            raw_response = response.content[0].text.strip()
            
            # Find the actual list in the response
            start_idx = raw_response.find('[')
            end_idx = raw_response.rfind(']') + 1
            
            if start_idx != -1 and end_idx != -1:
                list_str = raw_response[start_idx:end_idx]
                try:
                    # Convert simple character lists to full metadata format
                    if '"gender"' not in list_str and '"status"' not in list_str:
                        # This handles the case where we got a simple list of names
                        names = ast.literal_eval(list_str)
                        characters = []
                        for name in names:
                            # Basic gender detection
                            gender = 'F' if any(title in name for title in ['Fru ', 'Frøken ', 'Madame ']) else 'M'
                            characters.append({
                                "name": name,
                                "gender": gender,
                                "status": "",
                                "description": ""
                            })
                        return characters
                    else:
                        # Handle full metadata format
                        return ast.literal_eval(list_str)
                except Exception as e:
                    logging.error(f"Parse error for {play_title}: {str(e)}\nText: {list_str}")
                    return []
            else:
                logging.error(f"No list found in response for {play_title}")
                return []
            
        except Exception as e:
            logging.error(f"API error for {play_title}: {str(e)}")
            return []    
    def process_play(self, filepath: Path) -> Dict:
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                play_start = f.read(1000)
            
            characters = self.extract_characters_with_metadata(play_start, filepath.stem)
            
            play_info = {
                'title': filepath.stem,
                'characters': characters,
                'filepath': str(filepath),
                'character_count': len(characters),
                'gender_distribution': {
                    'M': sum(1 for c in characters if c['gender'] == 'M'),
                    'F': sum(1 for c in characters if c['gender'] == 'F')
                } if characters else {'M': 0, 'F': 0}
            }
            
            # Debug print to verify data
            print(f"\nProcessed {filepath.name}:")
            print(f"Found {len(characters)} characters")
            print("Play info:", json.dumps(play_info, indent=2, ensure_ascii=False))
            
            return play_info
            
        except Exception as e:
            print(f"Error processing {filepath}: {str(e)}")
            return {'title': filepath.stem, 'characters': [], 'filepath': str(filepath), 'character_count': 0}

    def process_all_plays(self, delay: float = 1.0) -> List[Dict]:
        play_files = list(self.plays_dir.glob('*.txt'))
        all_plays = []
        
        print(f"Found {len(play_files)} plays to process")
        
        for play_file in play_files:
            play_info = self.process_play(play_file)
            all_plays.append(play_info)
            print(f"Added to all_plays: {play_info['title']} with {len(play_info['characters'])} characters")
            sleep(delay)
        
        # Verify data before saving
        print("\nFinal data summary:")
        print(f"Total plays processed: {len(all_plays)}")
        print(f"Plays with characters: {sum(1 for p in all_plays if p['characters'])}")
        
        output_file = self.plays_dir / 'characters_with_metadata.json'
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(all_plays, f, indent=2, ensure_ascii=False)
        
        return all_plays

# %%
import os

api_key = os.getenv("ANTHROPIC_API_KEY")

# %%
# First create dataframe from the plays_data
df_plays = pd.DataFrame(plays_data)

# Explode the characters column - this will create one row per character
df_characters = df_plays.explode('characters')

# The characters column now contains dictionaries - we can normalize this
df_chars_normalized = pd.json_normalize(df_characters['characters'])

# Now combine with the play information
df_final = pd.concat([
    df_characters.drop('characters', axis=1).reset_index(drop=True),
    df_chars_normalized.reset_index(drop=True)
], axis=1)

# %%
df_final
# Out:
#              title                 filepath  character_count  \
# 0    stage_3971483  plays/stage_3971483.txt                9
# 1    stage_3971483  plays/stage_3971483.txt                9
# 2    stage_3971483  plays/stage_3971483.txt                9
# 3    stage_3971483  plays/stage_3971483.txt                9
# 4    stage_3971483  plays/stage_3971483.txt                9
# ..             ...                      ...              ...
# 569  stage_1563988  plays/stage_1563988.txt               14
# 570  stage_1563988  plays/stage_1563988.txt               14
# 571  stage_1563988  plays/stage_1563988.txt               14
# 572  stage_1563988  plays/stage_1563988.txt               14
# 573  stage_1563988  plays/stage_1563988.txt               14
#
#     gender_distribution         name gender                status description
# 0      {'M': 7, 'F': 2}       Sigrid      F                  None        None
# 1      {'M': 7, 'F': 2}     Ragnhild      F                  None        None
# 2      {'M': 7, 'F': 2}       Asmund      M                  None        None
# 3      {'M': 7, 'F': 2}       Nordal      M                  None        None
# 4      {'M': 7, 'F': 2}      Steenby      M             Studenter        None
# ..                  ...          ...    ...                   ...         ...
# 569   {'M': 10, 'F': 4}        Johan      M    hans Bontignedring
# 570   {'M': 10, 'F': 4}       Joseph      M  Falkenskjolds Tjener
# 571   {'M': 10, 'F': 4}         Berg      M        ham en Hofmand
# 572   {'M': 10, 'F': 4}  Præsidenten      M         i høieste Ret
# 573   {'M': 10, 'F': 4}     En Lagna      F
#
# [574 rows x 8 columns]

# %%
# Average characters per play
print("Average characters per play:", df_final.groupby('title').size().mean())

# Distribution of cast sizes
play_sizes = df_final.groupby('title').size()
print("\nPlay size distribution:")
print(play_sizes.describe())

# Gender balance per play
gender_by_play = df_final.groupby('title')['gender'].value_counts().unstack().fillna(0)
gender_by_play['total'] = gender_by_play.sum(axis=1)
gender_by_play['female_ratio'] = gender_by_play['F'] / gender_by_play['total']

print("\nGender ratio statistics:")
print(gender_by_play['female_ratio'].describe())

# Plays with most characters
print("\nPlays with largest casts:")
print(play_sizes.sort_values(ascending=False).head())

# Plays with most female characters
print("\nPlays with highest female representation (minimum 5 characters):")
print(gender_by_play[gender_by_play['total'] >= 5].sort_values('female_ratio', ascending=False).head())
# Out:
# Average characters per play: 10.436363636363636
#
# Play size distribution:
# count    55.000000
# mean     10.436364
# std       4.898086
# min       2.000000
# 25%       7.000000
# 50%       9.000000
# 75%      13.000000
# max      20.000000
# dtype: float64
#
# Gender ratio statistics:
# count    55.000000
# mean      0.323611
# std       0.145568
# min       0.000000
# 25%       0.226496
# 50%       0.333333
# 75%       0.428571
# max       0.666667
# Name: female_ratio, dtype: float64
#
# Plays with largest casts:
# title
# stage_1579379    20
# stage_1594255    20
# stage_1594283    20
# stage_1616602    20
# stage_1579380    18
# dtype: int64
#
# Plays with highest female representation (minimum 5 characters):
# gender           ?    F    M  M/F    N  total  female_ratio
# title
# stage_3971765  0.0  3.0  2.0  0.0  0.0    5.0      0.600000
# stage_1581443  0.0  4.0  3.0  0.0  0.0    7.0      0.571429
# stage_1564190  0.0  4.0  4.0  0.0  0.0    8.0      0.500000
# stage_1579385  0.0  4.0  4.0  0.0  0.0    8.0      0.500000
# stage_3970984  0.0  5.0  5.0  0.0  0.0   10.0      0.500000

# %%
# Check the result
print(df_final.head())
print("\nTotal characters:", len(df_final))
print("\nGender distribution:")
print(df_final['gender'].value_counts(normalize=True))
# Out:
#            title                 filepath  character_count  \
# 0  stage_3971483  plays/stage_3971483.txt                9
# 1  stage_3971483  plays/stage_3971483.txt                9
# 2  stage_3971483  plays/stage_3971483.txt                9
# 3  stage_3971483  plays/stage_3971483.txt                9
# 4  stage_3971483  plays/stage_3971483.txt                9
#
#   gender_distribution      name gender     status description
# 0    {'M': 7, 'F': 2}    Sigrid      F       None        None
# 1    {'M': 7, 'F': 2}  Ragnhild      F       None        None
# 2    {'M': 7, 'F': 2}    Asmund      M       None        None
# 3    {'M': 7, 'F': 2}    Nordal      M       None        None
# 4    {'M': 7, 'F': 2}   Steenby      M  Studenter        None
#
# Total characters: 574
#
# Gender distribution:
# gender
# M      0.688153
# F      0.299652
# M/F    0.008711
# ?      0.001742
# N      0.001742
# Name: proportion, dtype: float64

# %%
df_final[["title", "name", "gender", "status", "description"]].to_excel("Karakteranalyse.xlsx")

# %%
processor = NorwegianPlayProcessor(api_key, "./plays")
plays_data = processor.process_all_plays()

print(f"\nProsessert {len(plays_data)} skuespill")
# Out:
# Found 55 plays to process
#
# Processed stage_3971483.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_3971483",
#   "characters": [
#     {
#       "name": "Sigrid",
#       "gender": "F",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Ragnhild",
#       "gender": "F",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Asmund",
#       "gender": "M",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Nordal",
#       "gender": "M",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Steenby",
#       "gender": "M",
#       "status": "Studenter",
#       "description": null
#     },
#     {
#       "name": "Busk",
#       "gender": "M",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Skoleholderen",
#       "gender": "M",
#       "status": "Skoleholderen",
#       "description": null
#     },
#     {
#       "name": "Peer",
#       "gender": "M",
#       "status": null,
#       "description": null
#     },
#     {
#       "name": "Halvor",
#       "gender": "M",
#       "status": null,
#       "description": null
#     }
#   ],
#   "filepath": "plays/stage_3971483.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 7,
#     "F": 2
#   }
# }
# Added to all_plays: stage_3971483 with 9 characters
#
# Processed stage_3970963.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_3970963",
#   "characters": [
#     {
#       "name": "Holm",
#       "gender": "M",
#       "status": "Grosserer",
#       "description": ""
#     },
#     {
#       "name": "Martin",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Fru Holm",
#       "gender": "F",
#       "status": "Mange",
#       "description": ""
#     },
#     {
#       "name": "Emil",
#       "gender": "M",
#       "status": "deres Søn",
#       "description": ""
#     },
#     {
#       "name": "Ludvig",
#       "gender": "M",
#       "status": "hans Fætter",
#       "description": ""
#     },
#     {
#       "name": "Kona",
#       "gender": "F",
#       "status": "Frøk. Ved for",
#       "description": ""
#     },
#     {
#       "name": "Rosita",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Jens",
#       "gender": "M",
#       "status": "Karl hos Grossereren",
#       "description": ""
#     },
#     {
#       "name": "skisse",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3970963.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 6,
#     "F": 3
#   }
# }
# Added to all_plays: stage_3970963 with 9 characters
#
# Processed stage_3971267.txt:
# Found 13 characters
# Play info: {
#   "title": "stage_3971267",
#   "characters": [
#     {
#       "name": "Scheik Hassan",
#       "gender": "M",
#       "status": "rig Kjøbmand og Skriftlærd",
#       "description": ""
#     },
#     {
#       "name": "Sidi Numman",
#       "gender": "M",
#       "status": "Statholder i Balsora",
#       "description": ""
#     },
#     {
#       "name": "Prinds Achmet Mirza",
#       "gender": "M",
#       "status": "Prinds",
#       "description": ""
#     },
#     {
#       "name": "Suleika",
#       "gender": "F",
#       "status": "Datter af Fyrsten i Chorasan",
#       "description": ""
#     },
#     {
#       "name": "Emir Abu Muhammed",
#       "gender": "M",
#       "status": "Emir",
#       "description": ""
#     },
#     {
#       "name": "Ali Bachtjar",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Fatme",
#       "gender": "F",
#       "status": "en Enke",
#       "description": ""
#     },
#     {
#       "name": "Schemseddin",
#       "gender": "M",
#       "status": "Gavtyv",
#       "description": ""
#     },
#     {
#       "name": "Bedreddin",
#       "gender": "M",
#       "status": "Gavtyv",
#       "description": ""
#     },
#     {
#       "name": "Massud",
#       "gender": "M",
#       "status": "Negerslave hos Statholderen",
#       "description": ""
#     },
#     {
#       "name": "Mosaffer",
#       "gender": "M",
#       "status": "Opsynsmand hos Scheik Hassan",
#       "description": ""
#     },
#     {
#       "name": "Amine",
#       "gender": "F",
#       "status": "en ung Slavinde",
#       "description": "stum Person"
#     },
#     {
#       "name": "En Dreng",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971267.txt",
#   "character_count": 13,
#   "gender_distribution": {
#     "M": 10,
#     "F": 3
#   }
# }
# Added to all_plays: stage_3971267 with 13 characters
#
# Processed stage_1579397.txt:
# Found 7 characters
# Play info: {
#   "title": "stage_1579397",
#   "characters": [
#     {
#       "name": "Grevinde d'Autreval",
#       "gender": "F",
#       "status": "født Hermadio",
#       "description": ""
#     },
#     {
#       "name": "Leonie de la Villegontier",
#       "gender": "F",
#       "status": "hendes Niece",
#       "description": ""
#     },
#     {
#       "name": "Henri de Havegnet",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Gustave de Gregnen",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Baron de Montrichard",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "En Gensdage",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "En Tjener",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1579397.txt",
#   "character_count": 7,
#   "gender_distribution": {
#     "M": 5,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1579397 with 7 characters
#
# Processed stage_1564003.txt:
# Found 2 characters
# Play info: {
#   "title": "stage_1564003",
#   "characters": [
#     {
#       "name": "Bonnemain",
#       "gender": "M",
#       "status": "brudgom",
#       "description": "pyntet som Brudgom, kommer fra Baggrunden"
#     },
#     {
#       "name": "Bruden",
#       "gender": "F",
#       "status": "brud",
#       "description": "endnu ikke færdig"
#     }
#   ],
#   "filepath": "plays/stage_1564003.txt",
#   "character_count": 2,
#   "gender_distribution": {
#     "M": 1,
#     "F": 1
#   }
# }
# Added to all_plays: stage_1564003 with 2 characters
#
# Processed stage_1594278.txt:
# Found 11 characters
# Play info: {
#   "title": "stage_1594278",
#   "characters": [
#     {
#       "name": "Armand d'Albert de Boisse",
#       "gender": "M",
#       "status": "Frivillig i et Landseneer-Regiment",
#       "description": ""
#     },
#     {
#       "name": "Frederik",
#       "gender": "M",
#       "status": "Portraitmaler, Armands Ven",
#       "description": ""
#     },
#     {
#       "name": "Francois",
#       "gender": "M",
#       "status": "Tjener",
#       "description": ""
#     },
#     {
#       "name": "Emmeline",
#       "gender": "F",
#       "status": "ung Enke",
#       "description": ""
#     },
#     {
#       "name": "Alphonse Deshayes",
#       "gender": "M",
#       "status": "Oberst ved Regimentet",
#       "description": ""
#     },
#     {
#       "name": "Fru de Laroche",
#       "gender": "F",
#       "status": "Oberstens Søster",
#       "description": ""
#     },
#     {
#       "name": "Kirchet",
#       "gender": "M",
#       "status": "Vagtmester",
#       "description": ""
#     },
#     {
#       "name": "Marianne",
#       "gender": "F",
#       "status": "Gartnerske",
#       "description": ""
#     },
#     {
#       "name": "Canard",
#       "gender": "M",
#       "status": "Trompeter",
#       "description": ""
#     },
#     {
#       "name": "Pomponne",
#       "gender": "F",
#       "status": "Værtshuusholderske",
#       "description": ""
#     },
#     {
#       "name": "Laridon",
#       "gender": "M",
#       "status": "Landseneer",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1594278.txt",
#   "character_count": 11,
#   "gender_distribution": {
#     "M": 7,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1594278 with 11 characters
#
# Processed stage_1579385.txt:
# Found 8 characters
# Play info: {
#   "title": "stage_1579385",
#   "characters": [
#     {
#       "name": "Moren",
#       "gender": "F",
#       "status": "General",
#       "description": ""
#     },
#     {
#       "name": "Emil",
#       "gender": "M",
#       "status": "Hans Søn",
#       "description": ""
#     },
#     {
#       "name": "Fru Tor Morin",
#       "gender": "F",
#       "status": "Generalens Svigerinde",
#       "description": ""
#     },
#     {
#       "name": "Fru Mennier",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Joseph",
#       "gender": "M",
#       "status": "hendes Sønnebørn",
#       "description": ""
#     },
#     {
#       "name": "Elise",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Bipot",
#       "gender": "M",
#       "status": "Secretair",
#       "description": ""
#     },
#     {
#       "name": "Logik",
#       "gender": "M",
#       "status": "Tjener hos Generalen",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1579385.txt",
#   "character_count": 8,
#   "gender_distribution": {
#     "M": 4,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1579385 with 8 characters
#
# Processed stage_1563964.txt:
# Found 8 characters
# Play info: {
#   "title": "stage_1563964",
#   "characters": [
#     {
#       "name": "Nang",
#       "gender": "M",
#       "status": "Prinds af China",
#       "description": "Hr. Sahlers."
#     },
#     {
#       "name": "Tsing=Sing",
#       "gender": "M",
#       "status": "Mandarin",
#       "description": "— Phister."
#     },
#     {
#       "name": "Tchin=Kao",
#       "gender": "M",
#       "status": "Forpagter",
#       "description": "— Cetti."
#     },
#     {
#       "name": "Nang=Ko",
#       "gender": "M",
#       "status": "en ung Landmand",
#       "description": "— Schwartzen."
#     },
#     {
#       "name": "Stella",
#       "gender": "F",
#       "status": "Prindsesse af Hindustan",
#       "description": "Ifr. Kofod."
#     },
#     {
#       "name": "Tao=Jin",
#       "gender": "F",
#       "status": "Mandarinens Kone",
#       "description": "— Zrza."
#     },
#     {
#       "name": "Pe=Ki",
#       "gender": "F",
#       "status": "Forpagterens Datter",
#       "description": "Mdm. Krag."
#     },
#     {
#       "name": "Lo=Mang=Li",
#       "gender": "F",
#       "status": "Prindsessens Dame",
#       "description": "Ifr. Christensen."
#     }
#   ],
#   "filepath": "plays/stage_1563964.txt",
#   "character_count": 8,
#   "gender_distribution": {
#     "M": 4,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1563964 with 8 characters
#
# Processed stage_1587674.txt:
# Found 7 characters
# Play info: {
#   "title": "stage_1587674",
#   "characters": [
#     {
#       "name": "Grev Valoff",
#       "gender": "M",
#       "status": "Politimester",
#       "description": ""
#     },
#     {
#       "name": "Major Petrow",
#       "gender": "M",
#       "status": "Commandant paa Fæstningen Schlusselberg",
#       "description": ""
#     },
#     {
#       "name": "Fedora",
#       "gender": "F",
#       "status": "hans Datter",
#       "description": ""
#     },
#     {
#       "name": "Alexis Rationskje",
#       "gender": "M",
#       "status": "Lieutenant i den Keiserlige Garde",
#       "description": ""
#     },
#     {
#       "name": "Pager",
#       "gender": "M",
#       "status": "Officierer",
#       "description": ""
#     },
#     {
#       "name": "Hofdamer",
#       "gender": "F",
#       "status": "Hofdamer",
#       "description": ""
#     },
#     {
#       "name": "Herrer",
#       "gender": "M",
#       "status": "Herrer",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1587674.txt",
#   "character_count": 7,
#   "gender_distribution": {
#     "M": 5,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1587674 with 7 characters
#
# Processed stage_3971124.txt:
# Found 6 characters
# Play info: {
#   "title": "stage_3971124",
#   "characters": [
#     {
#       "name": "Halvard",
#       "gender": "M",
#       "status": "N/A",
#       "description": "N/A"
#     },
#     {
#       "name": "Bjørn",
#       "gender": "M",
#       "status": "hans Søn",
#       "description": "N/A"
#     },
#     {
#       "name": "Kaare",
#       "gender": "M",
#       "status": "Halvards Broder",
#       "description": "N/A"
#     },
#     {
#       "name": "Aslang",
#       "gender": "F",
#       "status": "Kaares Datter",
#       "description": "N/A"
#     },
#     {
#       "name": "Thrond",
#       "gender": "M",
#       "status": "N/A",
#       "description": "N/A"
#     },
#     {
#       "name": "Knut",
#       "gender": "M",
#       "status": "N/A",
#       "description": "N/A"
#     }
#   ],
#   "filepath": "plays/stage_3971124.txt",
#   "character_count": 6,
#   "gender_distribution": {
#     "M": 5,
#     "F": 1
#   }
# }
# Added to all_plays: stage_3971124 with 6 characters
#
# Processed stage_1558153.txt:
# Found 5 characters
# Play info: {
#   "title": "stage_1558153",
#   "characters": [
#     {
#       "name": "Madame de Neris",
#       "gender": "F",
#       "status": "en ung Enke",
#       "description": ""
#     },
#     {
#       "name": "Edvard",
#       "gender": "M",
#       "status": "hendes Gudson",
#       "description": ""
#     },
#     {
#       "name": "de Tordy",
#       "gender": "M",
#       "status": "Notarius",
#       "description": ""
#     },
#     {
#       "name": "Cecilie",
#       "gender": "F",
#       "status": "hans Søster",
#       "description": ""
#     },
#     {
#       "name": "Champenois",
#       "gender": "M",
#       "status": "Forpagter",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1558153.txt",
#   "character_count": 5,
#   "gender_distribution": {
#     "M": 3,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1558153 with 5 characters
#
# Processed stage_1594283.txt:
# Found 20 characters
# Play info: {
#   "title": "stage_1594283",
#   "characters": [
#     {
#       "name": "Emilie Galotti",
#       "gender": "F",
#       "status": "Tragisk heltinde",
#       "description": "Sørgespil af Lessing"
#     },
#     {
#       "name": "Paschaen af Suresne",
#       "gender": "M",
#       "status": "Hovedperson",
#       "description": "Comoedie af Etienne"
#     },
#     {
#       "name": "Landsbysangerinderne",
#       "gender": "F",
#       "status": "Hovedpersoner",
#       "description": "Syngestykke"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "original Lystspil af Overskou"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "ligeledes af Samme"
#     },
#     {
#       "name": "Romeo og Julie",
#       "gender": "M/F",
#       "status": "Tragiske elskende",
#       "description": "Tragoedie af Shakespeare"
#     },
#     {
#       "name": "Raupach",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Lystspil af Raupach"
#     },
#     {
#       "name": "Holcroft",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Comoedie af Holcroft"
#     },
#     {
#       "name": "Dupaty",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Syngestykke af Dupaty"
#     },
#     {
#       "name": "Skovhuggerens Søn",
#       "gender": "M",
#       "status": "Hovedperson",
#       "description": "Syngestykke af Planard"
#     },
#     {
#       "name": "P. A. Heiberg",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Syngestykke af P. A. Heiberg"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "original Lystspil af Overskou"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Lystspil af Scribe"
#     },
#     {
#       "name": "Holbein",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Lystspil af Holbein"
#     },
#     {
#       "name": "Valentine af Mayland",
#       "gender": "F",
#       "status": "Hovedperson",
#       "description": "Syngestykke af Bouilly"
#     },
#     {
#       "name": "Isidor og Olga",
#       "gender": "M/F",
#       "status": "Hovedpersoner",
#       "description": "Sørgespil af Raupach"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Syngestykke af Scribe"
#     },
#     {
#       "name": "Destillateuren",
#       "gender": "M",
#       "status": "Hovedperson",
#       "description": "original Vaudeville"
#     },
#     {
#       "name": "Den fortrædelige Formiddag",
#       "gender": "?",
#       "status": "Hovedperson(er)",
#       "description": "Lystspil"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "Forfatter",
#       "description": "Lystspil af Scribe"
#     }
#   ],
#   "filepath": "plays/stage_1594283.txt",
#   "character_count": 20,
#   "gender_distribution": {
#     "M": 14,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1594283 with 20 characters
#
# Processed stage_3971323.txt:
# Found 12 characters
# Play info: {
#   "title": "stage_3971323",
#   "characters": [
#     {
#       "name": "Guttorm",
#       "gender": "M",
#       "status": "Odelsbonde",
#       "description": ""
#     },
#     {
#       "name": "Helge",
#       "gender": "F",
#       "status": "hans Hustru",
#       "description": ""
#     },
#     {
#       "name": "Sigrid",
#       "gender": "F",
#       "status": "deres Datter",
#       "description": ""
#     },
#     {
#       "name": "Astrid",
#       "gender": "F",
#       "status": "deres Datter",
#       "description": ""
#     },
#     {
#       "name": "Styrk",
#       "gender": "M",
#       "status": "Skoleholder",
#       "description": ""
#     },
#     {
#       "name": "Arve",
#       "gender": "M",
#       "status": "Guttorms Grande",
#       "description": ""
#     },
#     {
#       "name": "Halvar",
#       "gender": "M",
#       "status": "hans Søn",
#       "description": ""
#     },
#     {
#       "name": "Præsten",
#       "gender": "M",
#       "status": "i Gjældet",
#       "description": ""
#     },
#     {
#       "name": "Brink",
#       "gender": "M",
#       "status": "en Reisende",
#       "description": ""
#     },
#     {
#       "name": "Asbjørn",
#       "gender": "M",
#       "status": "en gammel Bonde",
#       "description": ""
#     },
#     {
#       "name": "Hans Kvinde",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Bønderfolk",
#       "gender": "M/F",
#       "status": "Mænd, Kvinder, Gutter og Jenter",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971323.txt",
#   "character_count": 12,
#   "gender_distribution": {
#     "M": 7,
#     "F": 4
#   }
# }
# Added to all_plays: stage_3971323 with 12 characters
#
# Processed stage_1579380.txt:
# Found 18 characters
# Play info: {
#   "title": "stage_1579380",
#   "characters": [
#     {
#       "name": "Emilie Galotti",
#       "gender": "F",
#       "status": "Sørgespil",
#       "description": "af Lessing"
#     },
#     {
#       "name": "Paschaen af Suresne",
#       "gender": "M",
#       "status": "Comoedie",
#       "description": "af Etienne"
#     },
#     {
#       "name": "Landsbysangerinderne",
#       "gender": "F",
#       "status": "Syngestykke",
#       "description": ""
#     },
#     {
#       "name": "Tre Maaneder efter Brylluppet",
#       "gender": "M",
#       "status": "original Lystspil",
#       "description": "af Overskou"
#     },
#     {
#       "name": "Misforstaaelse paa Misforstaaelse",
#       "gender": "F",
#       "status": "ligeledes",
#       "description": "af Samme"
#     },
#     {
#       "name": "Romeo og Julie",
#       "gender": "M",
#       "status": "Tragoedie",
#       "description": "af Shakespeare"
#     },
#     {
#       "name": "Fred med de Døde",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": "af Raupach"
#     },
#     {
#       "name": "Veien til Ødelæggelse",
#       "gender": "F",
#       "status": "Comoedie",
#       "description": "af Holcroft"
#     },
#     {
#       "name": "De væltede Vogne",
#       "gender": "F",
#       "status": "Syngestykke",
#       "description": "af Dupaty"
#     },
#     {
#       "name": "Skovhuggerens Søn",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "af Planard"
#     },
#     {
#       "name": "Chinafarerne",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "af P. A. Heiber"
#     },
#     {
#       "name": "Østergade og Vestergade",
#       "gender": "M",
#       "status": "original Lystspil",
#       "description": "af Overskeu"
#     },
#     {
#       "name": "Gesandten",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": "af Scribe"
#     },
#     {
#       "name": "Efterskriften",
#       "gender": "F",
#       "status": "Lystspil",
#       "description": "af Holhein"
#     },
#     {
#       "name": "Valentine af Mayland",
#       "gender": "F",
#       "status": "Syngestykke",
#       "description": "af Bouilli"
#     },
#     {
#       "name": "Isidor og Olga",
#       "gender": "M",
#       "status": "Sørgespil",
#       "description": "af Raupach"
#     },
#     {
#       "name": "Muurmesteren",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "af Scribe"
#     },
#     {
#       "name": "Destillateuren",
#       "gender": "M",
#       "status": "original Vaudeville",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1579380.txt",
#   "character_count": 18,
#   "gender_distribution": {
#     "M": 11,
#     "F": 7
#   }
# }
# Added to all_plays: stage_1579380 with 18 characters
#
# Processed stage_1580805.txt:
# Found 10 characters
# Play info: {
#   "title": "stage_1580805",
#   "characters": [
#     {
#       "name": "Amalie",
#       "gender": "F",
#       "status": "regjerende Fyrstinde",
#       "description": ""
#     },
#     {
#       "name": "Edgard de Linberg",
#       "gender": "M",
#       "status": "hendes Privatsecretair",
#       "description": ""
#     },
#     {
#       "name": "Grev Henri",
#       "gender": "M",
#       "status": "Grev",
#       "description": ""
#     },
#     {
#       "name": "Mathilde",
#       "gender": "F",
#       "status": "ung Stiftsfrøken",
#       "description": ""
#     },
#     {
#       "name": "Charlotte",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Baron d'Anglure",
#       "gender": "M",
#       "status": "Charlottes Onkel, kammerherr",
#       "description": ""
#     },
#     {
#       "name": "Fyrstanden",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "En Betjent",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Hofdamer",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Cavallerer",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1580805.txt",
#   "character_count": 10,
#   "gender_distribution": {
#     "M": 6,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1580805 with 10 characters
#
# Processed stage_1594268.txt:
# Found 7 characters
# Play info: {
#   "title": "stage_1594268",
#   "characters": [
#     {
#       "name": "James Morton",
#       "gender": "M",
#       "status": "Qvæker",
#       "description": ""
#     },
#     {
#       "name": "Miss Georgina Barlow",
#       "gender": "F",
#       "status": "Dandserinde",
#       "description": ""
#     },
#     {
#       "name": "Arthur Darsie",
#       "gender": "M",
#       "status": "Marquis af Clifford, Pair af England",
#       "description": ""
#     },
#     {
#       "name": "Murray",
#       "gender": "M",
#       "status": "Lord Darsies Ven",
#       "description": ""
#     },
#     {
#       "name": "Toby",
#       "gender": "M",
#       "status": "Urtekræmmersvend",
#       "description": ""
#     },
#     {
#       "name": "En Tjener",
#       "gender": "M",
#       "status": "Tjener",
#       "description": ""
#     },
#     {
#       "name": "To unge Lords",
#       "gender": "M",
#       "status": "Lords",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1594268.txt",
#   "character_count": 7,
#   "gender_distribution": {
#     "M": 6,
#     "F": 1
#   }
# }
# Added to all_plays: stage_1594268 with 7 characters
#
# Processed stage_3971763.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_3971763",
#   "characters": [
#     {
#       "name": "Tordenskjold",
#       "gender": "M",
#       "status": "Commanden",
#       "description": ""
#     },
#     {
#       "name": "Steenfeldt",
#       "gender": "M",
#       "status": "svensk Socapitom",
#       "description": ""
#     },
#     {
#       "name": "Axel Sparre",
#       "gender": "M",
#       "status": "en Socadet",
#       "description": ""
#     },
#     {
#       "name": "",
#       "gender": "M",
#       "status": "En afskediget Major",
#       "description": ""
#     },
#     {
#       "name": "Henriette",
#       "gender": "F",
#       "status": "hans Datter",
#       "description": ""
#     },
#     {
#       "name": "Erik",
#       "gender": "M",
#       "status": "en Matros",
#       "description": ""
#     },
#     {
#       "name": "",
#       "gender": "M",
#       "status": "En Flok Drenge",
#       "description": ""
#     },
#     {
#       "name": "",
#       "gender": "M",
#       "status": "nogle Officerer",
#       "description": ""
#     },
#     {
#       "name": "",
#       "gender": "M",
#       "status": "Andre",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971763.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 8,
#     "F": 1
#   }
# }
# Added to all_plays: stage_3971763 with 9 characters
#
# Processed stage_1581439.txt:
# Found 3 characters
# Play info: {
#   "title": "stage_1581439",
#   "characters": [
#     {
#       "name": "Dormeuil",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Ernestine",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Marie",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581439.txt",
#   "character_count": 3,
#   "gender_distribution": {
#     "M": 1,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1581439 with 3 characters
#
# Processed stage_1558140.txt:
# Found 5 characters
# Play info: {
#   "title": "stage_1558140",
#   "characters": [
#     {
#       "name": "Madame de Neris",
#       "gender": "F",
#       "status": "en ung Enke",
#       "description": ""
#     },
#     {
#       "name": "Edvard",
#       "gender": "M",
#       "status": "hendes Gudsøn",
#       "description": ""
#     },
#     {
#       "name": "de Jordy",
#       "gender": "M",
#       "status": "Notarius",
#       "description": ""
#     },
#     {
#       "name": "Cecilie",
#       "gender": "F",
#       "status": "hans Søster",
#       "description": ""
#     },
#     {
#       "name": "Champenous",
#       "gender": "M",
#       "status": "Forpagter",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1558140.txt",
#   "character_count": 5,
#   "gender_distribution": {
#     "M": 3,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1558140 with 5 characters
#
# Processed stage_1582084.txt:
# Found 16 characters
# Play info: {
#   "title": "stage_1582084",
#   "characters": [
#     {
#       "name": "Adrienne Lecouvreur",
#       "gender": "F",
#       "status": "Skuespillerinde ved den franske Scene",
#       "description": ""
#     },
#     {
#       "name": "Maurice",
#       "gender": "M",
#       "status": "Greve af Sachsen",
#       "description": ""
#     },
#     {
#       "name": "Prindsen af Bouillon",
#       "gender": "M",
#       "status": "Prindsen af Bouillon",
#       "description": ""
#     },
#     {
#       "name": "Prindsessen",
#       "gender": "F",
#       "status": "Prindsessen af Bouillon",
#       "description": "Hans Kone"
#     },
#     {
#       "name": "Abbeden af Chazel",
#       "gender": "M",
#       "status": "Abbeden af Chazel",
#       "description": ""
#     },
#     {
#       "name": "Athenais",
#       "gender": "F",
#       "status": "Hertugende af",
#       "description": ""
#     },
#     {
#       "name": "Michonnet",
#       "gender": "M",
#       "status": "Regissør",
#       "description": ""
#     },
#     {
#       "name": "Fru Goussin",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Marquisen",
#       "gender": "F",
#       "status": "Marquisen",
#       "description": ""
#     },
#     {
#       "name": "Frk. Jouvenot",
#       "gender": "F",
#       "status": "",
#       "description": "Skuespillerinde"
#     },
#     {
#       "name": "Fru Dangeville",
#       "gender": "F",
#       "status": "",
#       "description": "Skuespillerinde"
#     },
#     {
#       "name": "Hr. Quinault",
#       "gender": "M",
#       "status": "",
#       "description": "Skuespiller"
#     },
#     {
#       "name": "Poisson",
#       "gender": "M",
#       "status": "",
#       "description": "Skuespiller"
#     },
#     {
#       "name": "En Tjener for Prindsessen",
#       "gender": "M",
#       "status": "Tjener for Prindsessen",
#       "description": ""
#     },
#     {
#       "name": "Et Theaterbud",
#       "gender": "M",
#       "status": "Theaterbud",
#       "description": ""
#     },
#     {
#       "name": "En Tjener for Adrienne",
#       "gender": "M",
#       "status": "Tjener for Adrienne",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1582084.txt",
#   "character_count": 16,
#   "gender_distribution": {
#     "M": 9,
#     "F": 7
#   }
# }
# Added to all_plays: stage_1582084 with 16 characters
#
# Processed stage_1564166.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_1564166",
#   "characters": [
#     {
#       "name": "Arthur de Morangy",
#       "gender": "M",
#       "status": "Hertug",
#       "description": ""
#     },
#     {
#       "name": "Albert",
#       "gender": "M",
#       "status": "Grev",
#       "description": ""
#     },
#     {
#       "name": "Nogent",
#       "gender": "M",
#       "status": "Hertugens kammertjener",
#       "description": ""
#     },
#     {
#       "name": "Baronesse von Schaffenburg",
#       "gender": "F",
#       "status": "Baronesse",
#       "description": ""
#     },
#     {
#       "name": "Cecilie",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Munch",
#       "gender": "M",
#       "status": "Jæger hos Baronessen",
#       "description": ""
#     },
#     {
#       "name": "Officerer",
#       "gender": "M",
#       "status": "Officerer",
#       "description": ""
#     },
#     {
#       "name": "Damer",
#       "gender": "F",
#       "status": "Damer",
#       "description": ""
#     },
#     {
#       "name": "Tjenere",
#       "gender": "M",
#       "status": "Tjenere",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1564166.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 6,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1564166 with 9 characters
#
# Processed stage_1594274.txt:
# Found 15 characters
# Play info: {
#   "title": "stage_1594274",
#   "characters": [
#     {
#       "name": "Barbeau",
#       "gender": "M",
#       "status": "farmer",
#       "description": ""
#     },
#     {
#       "name": "Mor Barbeau",
#       "gender": "F",
#       "status": "farmer's wife",
#       "description": "klædt i en Velstands-Bondekonedragt, staar ved Vinduet og ser ud med megen Uro"
#     },
#     {
#       "name": "Landry",
#       "gender": "M",
#       "status": "son of Barbeau and Mor Barbeau",
#       "description": ""
#     },
#     {
#       "name": "Didier",
#       "gender": "M",
#       "status": "son of Barbeau and Mor Barbeau",
#       "description": ""
#     },
#     {
#       "name": "Martineau",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Etienne",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Collin",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "le Fadette",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Tanchon Viveir",
#       "gender": "F",
#       "status": "granddaughter of le Fadette",
#       "description": ""
#     },
#     {
#       "name": "Hanon",
#       "gender": "M",
#       "status": "godfather of Tanchon Viveir",
#       "description": ""
#     },
#     {
#       "name": "Caillard",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Madelone",
#       "gender": "F",
#       "status": "daughter of Caillard",
#       "description": ""
#     },
#     {
#       "name": "Lusette",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Mariette",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Anette",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1594274.txt",
#   "character_count": 15,
#   "gender_distribution": {
#     "M": 8,
#     "F": 7
#   }
# }
# Added to all_plays: stage_1594274 with 15 characters
#
# Processed stage_1581433.txt:
# Found 13 characters
# Play info: {
#   "title": "stage_1581433",
#   "characters": [
#     {
#       "name": "Hr. Nogen",
#       "gender": "M",
#       "status": "har Datten",
#       "description": ""
#     },
#     {
#       "name": "Lorte",
#       "gender": "F",
#       "status": "hans Broderdatter",
#       "description": ""
#     },
#     {
#       "name": "Bärtel",
#       "gender": "M",
#       "status": "hans Broderdatter",
#       "description": "Han kan Fra Welt"
#     },
#     {
#       "name": "Reinhard",
#       "gender": "M",
#       "status": "Maleri",
#       "description": ""
#     },
#     {
#       "name": "Reisemegen",
#       "gender": "M",
#       "status": "Ballaborator ved Kystens Bibliothek",
#       "description": ""
#     },
#     {
#       "name": "Christoffer Bolden",
#       "gender": "M",
#       "status": "en ung Bonde",
#       "description": ""
#     },
#     {
#       "name": "Holmberg",
#       "gender": "M",
#       "status": "Opvarten i Linden",
#       "description": ""
#     },
#     {
#       "name": "Masten",
#       "gender": "M",
#       "status": "Opvarten i Linden",
#       "description": ""
#     },
#     {
#       "name": "En Bonde",
#       "gender": "M",
#       "status": "En Bonde",
#       "description": ""
#     },
#     {
#       "name": "Systen",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Hr. Dr. Ide",
#       "gender": "M",
#       "status": "komne af Petieck",
#       "description": ""
#     },
#     {
#       "name": "En repai Bog",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Amalie",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581433.txt",
#   "character_count": 13,
#   "gender_distribution": {
#     "M": 10,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1581433 with 13 characters
#
# Processed stage_1594281.txt:
# Found 8 characters
# Play info: {
#   "title": "stage_1594281",
#   "characters": [
#     {
#       "name": "Hilarion",
#       "gender": "M",
#       "status": "Gerard's servant",
#       "description": "Gerard's servant"
#     },
#     {
#       "name": "Oscar",
#       "gender": "M",
#       "status": "Marquisen's nephew",
#       "description": ""
#     },
#     {
#       "name": "Gerard",
#       "gender": "M",
#       "status": "landowner",
#       "description": ""
#     },
#     {
#       "name": "Marquisen",
#       "gender": "F",
#       "status": "noblewoman",
#       "description": ""
#     },
#     {
#       "name": "Fru Parelius",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Ninette",
#       "gender": "F",
#       "status": "",
#       "description": "Fru Remning"
#     },
#     {
#       "name": "En Naturius",
#       "gender": "M",
#       "status": "",
#       "description": "Hr Simonsen"
#     },
#     {
#       "name": "Bøndenfolk",
#       "gender": "M",
#       "status": "peasants",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1594281.txt",
#   "character_count": 8,
#   "gender_distribution": {
#     "M": 5,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1594281 with 8 characters
#
# Processed stage_1616602.txt:
# Found 20 characters
# Play info: {
#   "title": "stage_1616602",
#   "characters": [
#     {
#       "name": "Emilie Galotti",
#       "gender": "F",
#       "status": "Sørgespil",
#       "description": "af Lessing"
#     },
#     {
#       "name": "Paschaen af Suresne",
#       "gender": "M",
#       "status": "Comoedie",
#       "description": "af Etienne"
#     },
#     {
#       "name": "Landsbysangerinderne",
#       "gender": "F",
#       "status": "Syngestykke",
#       "description": ""
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "original Lystspil",
#       "description": "Tre Maaneder efter Brylluppet"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "ligeledes",
#       "description": "Misforstaaelse paa Misforstaaelse"
#     },
#     {
#       "name": "Romeo og Julie",
#       "gender": "M",
#       "status": "Tragoedie",
#       "description": "af Shakespeare"
#     },
#     {
#       "name": "Raupach",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": "Fred med de Døde"
#     },
#     {
#       "name": "Holcroft",
#       "gender": "M",
#       "status": "Comoedie",
#       "description": "Veien til Ødelæggelse"
#     },
#     {
#       "name": "Dupaty",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "De væltede Vogne"
#     },
#     {
#       "name": "Planard",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "Skovhuggerens Søn"
#     },
#     {
#       "name": "P. A. Heiberg",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "Chinafarerne"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "original Lystspil",
#       "description": "Østergade og Vestergade"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": "Gesandten"
#     },
#     {
#       "name": "Holbein",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": "Efterskriften"
#     },
#     {
#       "name": "Valentine af Mayland",
#       "gender": "F",
#       "status": "Syngestykke",
#       "description": "af Bouilly"
#     },
#     {
#       "name": "Isidor og Olga",
#       "gender": "M",
#       "status": "Sørgespil",
#       "description": "af Raupach"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "Syngestykke",
#       "description": "Muurmesteren"
#     },
#     {
#       "name": "Destillateuren",
#       "gender": "M",
#       "status": "original Vaudeville",
#       "description": ""
#     },
#     {
#       "name": "Den fortrædelige Formiddag",
#       "gender": "F",
#       "status": "Lystspil",
#       "description": ""
#     },
#     {
#       "name": "Formynder og Myndling",
#       "gender": "M",
#       "status": "Lystspil",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1616602.txt",
#   "character_count": 20,
#   "gender_distribution": {
#     "M": 16,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1616602 with 20 characters
#
# Processed stage_1581578.txt:
# Found 3 characters
# Play info: {
#   "title": "stage_1581578",
#   "characters": [
#     {
#       "name": "Velasquez",
#       "gender": "M",
#       "status": "Maler",
#       "description": ""
#     },
#     {
#       "name": "Palomita",
#       "gender": "F",
#       "status": "Velasquez's Huusholderske",
#       "description": ""
#     },
#     {
#       "name": "Perdican",
#       "gender": "M",
#       "status": "hans Ven, Politimand",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581578.txt",
#   "character_count": 3,
#   "gender_distribution": {
#     "M": 2,
#     "F": 1
#   }
# }
# Added to all_plays: stage_1581578 with 3 characters
#
# Processed stage_1594263.txt:
# Found 12 characters
# Play info: {
#   "title": "stage_1594263",
#   "characters": [
#     {
#       "name": "Tanne",
#       "gender": "M",
#       "status": "en gammel Skuespiller",
#       "description": ""
#     },
#     {
#       "name": "Athanasia",
#       "gender": "F",
#       "status": "hans Datter",
#       "description": ""
#     },
#     {
#       "name": "Grev Ernest",
#       "gender": "M",
#       "status": "Grev",
#       "description": ""
#     },
#     {
#       "name": "Mad. Müller-Schuls",
#       "gender": "F",
#       "status": "Skuespillerinde",
#       "description": ""
#     },
#     {
#       "name": "Doktor Spinne",
#       "gender": "M",
#       "status": "Theaterdigter",
#       "description": ""
#     },
#     {
#       "name": "Brulle",
#       "gender": "M",
#       "status": "Redaktør",
#       "description": ""
#     },
#     {
#       "name": "To Journalister",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Theaterdirektøren",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Regissoren",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "En Skuespiller",
#       "gender": "M",
#       "status": "Skuespiller",
#       "description": ""
#     },
#     {
#       "name": "En Skuespillerinde",
#       "gender": "F",
#       "status": "Skuespillerinde",
#       "description": ""
#     },
#     {
#       "name": "Et Theaterbud",
#       "gender": "N",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1594263.txt",
#   "character_count": 12,
#   "gender_distribution": {
#     "M": 8,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1594263 with 12 characters
#
# Processed stage_1587724.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_1587724",
#   "characters": [
#     {
#       "name": "Dronning Anna",
#       "gender": "F",
#       "status": "Dronning",
#       "description": ""
#     },
#     {
#       "name": "Hertuginden af Marborough",
#       "gender": "F",
#       "status": "Hertuginde",
#       "description": "hendes yndling"
#     },
#     {
#       "name": "Henry St. John Bolingbroke",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Arthur Masham",
#       "gender": "M",
#       "status": "Fændrik i Garden",
#       "description": ""
#     },
#     {
#       "name": "Abigall",
#       "gender": "F",
#       "status": "Hertuginden af Marlboroughs Cousine",
#       "description": ""
#     },
#     {
#       "name": "Marquis de Tony",
#       "gender": "M",
#       "status": "Ludvig den Fjortendes Ambassaden",
#       "description": ""
#     },
#     {
#       "name": "Thomshon",
#       "gender": "M",
#       "status": "Dronningens Sørvagter",
#       "description": ""
#     },
#     {
#       "name": "Et Parlamentslem",
#       "gender": "M",
#       "status": "Parlamentslem",
#       "description": ""
#     },
#     {
#       "name": "En Ceremonimester",
#       "gender": "M",
#       "status": "Ceremonimester",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1587724.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 6,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1587724 with 9 characters
#
# Processed stage_3971423.txt:
# Found 8 characters
# Play info: {
#   "title": "stage_3971423",
#   "characters": [
#     {
#       "name": "Grev til Tuente",
#       "gender": "M",
#       "status": "nobleman",
#       "description": ""
#     },
#     {
#       "name": "Sørgensen",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Clara",
#       "gender": "F",
#       "status": "wife of Grev til Tuente",
#       "description": ""
#     },
#     {
#       "name": "Berg",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Don Fernanda",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Maja",
#       "gender": "F",
#       "status": "Clara's chambermaid",
#       "description": ""
#     },
#     {
#       "name": "En Muursvend",
#       "gender": "M",
#       "status": "mason",
#       "description": ""
#     },
#     {
#       "name": "En Tjener",
#       "gender": "M",
#       "status": "servant",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971423.txt",
#   "character_count": 8,
#   "gender_distribution": {
#     "M": 6,
#     "F": 2
#   }
# }
# Added to all_plays: stage_3971423 with 8 characters
#
# Processed stage_1579379.txt:
# Found 20 characters
# Play info: {
#   "title": "stage_1579379",
#   "characters": [
#     {
#       "name": "Emilie Galotti",
#       "gender": "F",
#       "status": "character in a tragedy",
#       "description": "Sørgespil af Lessing"
#     },
#     {
#       "name": "Landsbysangerinderne",
#       "gender": "F",
#       "status": "characters in a musical play",
#       "description": "Syngestykke"
#     },
#     {
#       "name": "Tre Maaneder efter Brylluppet",
#       "gender": "M",
#       "status": "characters in an original comedy",
#       "description": "original Lystspil af Overskou"
#     },
#     {
#       "name": "Fred med de Døde",
#       "gender": "M",
#       "status": "characters in a comedy",
#       "description": "Lystspil af Raupach"
#     },
#     {
#       "name": "Veien til Ødelæggelse",
#       "gender": "M",
#       "status": "characters in a comedy",
#       "description": "Comoedie af Holcroft"
#     },
#     {
#       "name": "De væltede Vogne",
#       "gender": "M",
#       "status": "characters in a musical play",
#       "description": "Syngestykke af Dupaty"
#     },
#     {
#       "name": "Skovhuggerens Søn",
#       "gender": "M",
#       "status": "characters in a musical play",
#       "description": "Syngestykke af Planard"
#     },
#     {
#       "name": "Chinafarerne",
#       "gender": "M",
#       "status": "characters in a musical play",
#       "description": "Syngestykke af P. A. Heiberg"
#     },
#     {
#       "name": "Efterskriften",
#       "gender": "M",
#       "status": "characters in a comedy",
#       "description": "Lystspil af Holbein"
#     },
#     {
#       "name": "Valentine af Mayland",
#       "gender": "F",
#       "status": "character in a musical play",
#       "description": "Syngestykke af Bouilly"
#     },
#     {
#       "name": "Isidor og Olga",
#       "gender": "M",
#       "status": "characters in a tragedy",
#       "description": "Sørgespil af Raupach"
#     },
#     {
#       "name": "Muurmesteren",
#       "gender": "M",
#       "status": "character in a musical play",
#       "description": "Syngestykke af Scribe"
#     },
#     {
#       "name": "Destillateuren",
#       "gender": "M",
#       "status": "characters in an original vaudeville",
#       "description": "original Vaudeville"
#     },
#     {
#       "name": "Den fortrædelige Formiddag",
#       "gender": "F",
#       "status": "characters in a comedy",
#       "description": "Lystspil"
#     },
#     {
#       "name": "Formynder og Myndling",
#       "gender": "M",
#       "status": "characters in a comedy",
#       "description": "Lystspil af Scribe"
#     },
#     {
#       "name": "Snyltegjæsten",
#       "gender": "M",
#       "status": "character in a comedy",
#       "description": "ligeledes af Samme"
#     },
#     {
#       "name": "Hellig Tre Kongers Aften",
#       "gender": "M",
#       "status": "characters in a comedy",
#       "description": "Lystspil af Shakespeare"
#     },
#     {
#       "name": "Hvilken er den Rette?",
#       "gender": "M",
#       "status": "characters in an original vaudeville",
#       "description": "original Vaudeville af Overskou"
#     },
#     {
#       "name": "De muntre Koner",
#       "gender": "F",
#       "status": "characters in a comedy",
#       "description": "Lystspil af Shakespeare"
#     },
#     {
#       "name": "Vor Tids Mennesker",
#       "gender": "M",
#       "status": "characters in an original comedy",
#       "description": "originalt Lystspil af Overskou"
#     }
#   ],
#   "filepath": "plays/stage_1579379.txt",
#   "character_count": 20,
#   "gender_distribution": {
#     "M": 15,
#     "F": 5
#   }
# }
# Added to all_plays: stage_1579379 with 20 characters
#
# Processed stage_3971123.txt:
# Found 5 characters
# Play info: {
#   "title": "stage_3971123",
#   "characters": [
#     {
#       "name": "Thorberg Arnessøn",
#       "gender": "M",
#       "status": "Herre til Giske",
#       "description": ""
#     },
#     {
#       "name": "Ragnhild Erlingsdatter",
#       "gender": "F",
#       "status": "hans Hustru",
#       "description": ""
#     },
#     {
#       "name": "Eystein Orre",
#       "gender": "M",
#       "status": "deres Søn, en Dreng paa 14 Aar",
#       "description": ""
#     },
#     {
#       "name": "Stein Skaftessøn",
#       "gender": "M",
#       "status": "en ung Islænder",
#       "description": ""
#     },
#     {
#       "name": "En Fremmed",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971123.txt",
#   "character_count": 5,
#   "gender_distribution": {
#     "M": 4,
#     "F": 1
#   }
# }
# Added to all_plays: stage_3971123 with 5 characters
#
# Processed stage_3971543.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_3971543",
#   "characters": [
#     {
#       "name": "Toget",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Hasting",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Emilie",
#       "gender": "F",
#       "status": "hans Datter",
#       "description": ""
#     },
#     {
#       "name": "Blinch",
#       "gender": "M",
#       "status": "Student",
#       "description": ""
#     },
#     {
#       "name": "Grim",
#       "gender": "M",
#       "status": "Lensmand",
#       "description": ""
#     },
#     {
#       "name": "Ole Høiland",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Jens",
#       "gender": "M",
#       "status": "Gaardskal hos Hasting",
#       "description": ""
#     },
#     {
#       "name": "Mons",
#       "gender": "M",
#       "status": "Gaardskal hos Grim",
#       "description": ""
#     },
#     {
# ...
#       "name": "Therese",
#       "gender": "F",
#       "status": "hans Søsterdatter",
#       "description": "Ifr. Kofod"
#     },
#     {
#       "name": "Jouché",
#       "gender": "M",
#       "status": "Politieminister",
#       "description": "Hr. Stage"
#     },
#     {
#       "name": "Désaunais",
#       "gender": "M",
#       "status": "Politieinspecteur",
#       "description": "— Phister"
#     },
#     {
#       "name": "Bernard",
#       "gender": "M",
#       "status": "Snedker",
#       "description": ""
#     },
#     {
#       "name": "Jules de Crussac",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Rosenkilde",
#       "gender": "M",
#       "status": "Hr.",
#       "description": "Personerne"
#     },
#     {
#       "name": "Schwartzen",
#       "gender": "M",
#       "status": "",
#       "description": "Personerne"
#     },
#     {
#       "name": "Waltz",
#       "gender": "M",
#       "status": "",
#       "description": "Personerne"
#     },
#     {
#       "name": "Armagnac",
#       "gender": "M",
#       "status": "",
#       "description": "Hr. Hansen"
#     },
#     {
#       "name": "Desort",
#       "gender": "M",
#       "status": "",
#       "description": "— Salhgreen"
#     },
#     {
#       "name": "En Politie=Fuldmægtig",
#       "gender": "M",
#       "status": "",
#       "description": "— Winsløv"
#     },
#     {
#       "name": "En Politie=Betjent",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Brock",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Politie=Fuldmægtiger og Betjenter",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Gendarmer",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1580816.txt",
#   "character_count": 16,
#   "gender_distribution": {
#     "M": 15,
#     "F": 1
#   }
# }
# Added to all_plays: stage_1580816 with 16 characters
#
# Processed stage_1564190.txt:
# Found 8 characters
# Play info: {
#   "title": "stage_1564190",
#   "characters": [
#     {
#       "name": "Jang",
#       "gender": "M",
#       "status": "Prinds af China",
#       "description": ""
#     },
#     {
#       "name": "Tsing-Sing",
#       "gender": "M",
#       "status": "Mandarin",
#       "description": ""
#     },
#     {
#       "name": "Tchin-Kao",
#       "gender": "M",
#       "status": "Forpagter",
#       "description": ""
#     },
#     {
#       "name": "Nang-Ko",
#       "gender": "M",
#       "status": "en ung Landmand",
#       "description": ""
#     },
#     {
#       "name": "Stella",
#       "gender": "F",
#       "status": "Prindsesse af Hindustan",
#       "description": ""
#     },
#     {
#       "name": "Tao-Jin",
#       "gender": "F",
#       "status": "Mandarinens Kone",
#       "description": ""
#     },
#     {
#       "name": "Pe-Ki",
#       "gender": "F",
#       "status": "Forpagterens Datter",
#       "description": ""
#     },
#     {
#       "name": "Lo-Mang-Li",
#       "gender": "F",
#       "status": "Prindsessens Dame",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1564190.txt",
#   "character_count": 8,
#   "gender_distribution": {
#     "M": 4,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1564190 with 8 characters
#
# Processed stage_3971765.txt:
# Found 5 characters
# Play info: {
#   "title": "stage_3971765",
#   "characters": [
#     {
#       "name": "Fru",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Frøken",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Madame",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Herr",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Hr.",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971765.txt",
#   "character_count": 5,
#   "gender_distribution": {
#     "M": 2,
#     "F": 3
#   }
# }
# Added to all_plays: stage_3971765 with 5 characters
#
# Processed stage_1581567.txt:
# Found 11 characters
# Play info: {
#   "title": "stage_1581567",
#   "characters": [
#     {
#       "name": "Nicob Jenkind",
#       "gender": "M",
#       "status": "rig engelsk Kjøbmand",
#       "description": ""
#     },
#     {
#       "name": "Ordelig",
#       "gender": "F",
#       "status": "hans Datter",
#       "description": ""
#     },
#     {
#       "name": "Tullivan",
#       "gender": "M",
#       "status": "Skuespiller ved Drurylane-Theatret",
#       "description": ""
#     },
#     {
#       "name": "Tir Frederik Dumple",
#       "gender": "M",
#       "status": "tenkes Neveuer",
#       "description": ""
#     },
#     {
#       "name": "Saunders",
#       "gender": "M",
#       "status": "Varemæglet",
#       "description": ""
#     },
#     {
#       "name": "bistrers Taunders",
#       "gender": "F",
#       "status": "hans Kone",
#       "description": ""
#     },
#     {
#       "name": "Hensyn",
#       "gender": "M",
#       "status": "Tilkehandler",
#       "description": ""
#     },
#     {
#       "name": "Miss Seneløpe",
#       "gender": "F",
#       "status": "hans Søster",
#       "description": ""
#     },
#     {
#       "name": "Cock",
#       "gender": "M",
#       "status": "Advokat",
#       "description": ""
#     },
#     {
#       "name": "Litte-John",
#       "gender": "M",
#       "status": "Tjener hos Jensens",
#       "description": ""
#     },
#     {
#       "name": "Dickson",
#       "gender": "M",
#       "status": "Tjener hos Pullivan",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581567.txt",
#   "character_count": 11,
#   "gender_distribution": {
#     "M": 8,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1581567 with 11 characters
#
# Processed stage_1581843.txt:
# Found 9 characters
# Play info: {
#   "title": "stage_1581843",
#   "characters": [
#     {
#       "name": "Ernestine de Reuvray",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Mad. Hundevist",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Aftense i Auberive",
#       "gender": "M",
#       "status": "hendes tilkommende",
#       "description": ""
#     },
#     {
#       "name": "Frøkenen",
#       "gender": "F",
#       "status": "Datter af den gamle Slotsgartner",
#       "description": ""
#     },
#     {
#       "name": "Dumont",
#       "gender": "M",
#       "status": "Forvalter",
#       "description": ""
#     },
#     {
#       "name": "Pierre Rousselet",
#       "gender": "M",
#       "status": "Forpagter",
#       "description": ""
#     },
#     {
#       "name": "Andre",
#       "gender": "M",
#       "status": "Gartnerdring",
#       "description": ""
#     },
#     {
#       "name": "Herrer og Damer",
#       "gender": "M/F",
#       "status": "Gjæster paa Slottet",
#       "description": ""
#     },
#     {
#       "name": "Tjenere og Landsbyfolk",
#       "gender": "M/F",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581843.txt",
#   "character_count": 9,
#   "gender_distribution": {
#     "M": 4,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1581843 with 9 characters
#
# Processed stage_1564183.txt:
# Found 18 characters
# Play info: {
#   "title": "stage_1564183",
#   "characters": [
#     {
#       "name": "Emilie Galotti",
#       "gender": "F",
#       "status": "",
#       "description": "Sørgespil af Lessing"
#     },
#     {
#       "name": "Landsbysangerinderne",
#       "gender": "F",
#       "status": "",
#       "description": "Syngestykke"
#     },
#     {
#       "name": "Overskou",
#       "gender": "M",
#       "status": "",
#       "description": "original Lystspil af Overskou"
#     },
#     {
#       "name": "Raupach",
#       "gender": "M",
#       "status": "",
#       "description": "Lystspil af Raupach"
#     },
#     {
#       "name": "Holcroft",
#       "gender": "M",
#       "status": "",
#       "description": "Comoedie af Holcroft"
#     },
#     {
#       "name": "Dupaty",
#       "gender": "M",
#       "status": "",
#       "description": "Syngestykke af Dupaty"
#     },
#     {
#       "name": "Planard",
#       "gender": "M",
#       "status": "",
#       "description": "Syngestykke af Planard"
#     },
#     {
#       "name": "P. A. Heiberg",
#       "gender": "M",
#       "status": "",
#       "description": "Syngestykke af P. A. Heiberg"
#     },
#     {
#       "name": "Holbein",
#       "gender": "M",
#       "status": "",
#       "description": "Lystspil af Holbein"
#     },
#     {
#       "name": "Bouilly",
#       "gender": "M",
#       "status": "",
#       "description": "Syngestykke af Bouilly"
#     },
#     {
#       "name": "Isidor",
#       "gender": "M",
#       "status": "",
#       "description": "Sørgespil af Raupach"
#     },
#     {
#       "name": "Olga",
#       "gender": "F",
#       "status": "",
#       "description": "Sørgespil af Raupach"
#     },
#     {
#       "name": "Scribe",
#       "gender": "M",
#       "status": "",
#       "description": "Syngestykke af Scribe"
#     },
#     {
#       "name": "Destillateuren",
#       "gender": "M",
#       "status": "",
#       "description": "original Vaudeville"
#     },
#     {
#       "name": "Formynder",
#       "gender": "M",
#       "status": "",
#       "description": "Lystspil af Scribe"
#     },
#     {
#       "name": "Myndling",
#       "gender": "M",
#       "status": "",
#       "description": "Lystspil af Scribe"
#     },
#     {
#       "name": "Snyltegjæsten",
#       "gender": "M",
#       "status": "",
#       "description": "ligeledes af Samme"
#     },
#     {
#       "name": "Shakespeare",
#       "gender": "M",
#       "status": "",
#       "description": "Lystspil af Shakespeare"
#     }
#   ],
#   "filepath": "plays/stage_1564183.txt",
#   "character_count": 18,
#   "gender_distribution": {
#     "M": 15,
#     "F": 3
#   }
# }
# Added to all_plays: stage_1564183 with 18 characters
#
# Processed stage_3971505.txt:
# Found 7 characters
# Play info: {
#   "title": "stage_3971505",
#   "characters": [
#     {
#       "name": "Kambert",
#       "gender": "M",
#       "status": "Advokat",
#       "description": ""
#     },
#     {
#       "name": "Baron Chateaunen",
#       "gender": "M",
#       "status": "Baron",
#       "description": ""
#     },
#     {
#       "name": "Hermann",
#       "gender": "M",
#       "status": "hans Søn",
#       "description": ""
#     },
#     {
#       "name": "Elemence",
#       "gender": "F",
#       "status": "Kamberts Datter",
#       "description": ""
#     },
#     {
#       "name": "Mr. Durand",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "En Secretair",
#       "gender": "M",
#       "status": "Secretair",
#       "description": ""
#     },
#     {
#       "name": "en Tjener",
#       "gender": "M",
#       "status": "Tjener",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_3971505.txt",
#   "character_count": 7,
#   "gender_distribution": {
#     "M": 6,
#     "F": 1
#   }
# }
# Added to all_plays: stage_3971505 with 7 characters
#
# Processed stage_1587693.txt:
# Found 11 characters
# Play info: {
#   "title": "stage_1587693",
#   "characters": [
#     {
#       "name": "Emmeric Albert",
#       "gender": "M",
#       "status": "ung Componist",
#       "description": ""
#     },
#     {
#       "name": "Clerambeau",
#       "gender": "M",
#       "status": "Kjøbmand, hans Onkel",
#       "description": ""
#     },
#     {
#       "name": "Aline",
#       "gender": "F",
#       "status": "Clerambeaus Datter",
#       "description": ""
#     },
#     {
#       "name": "Grev de Saint Geran",
#       "gender": "M",
#       "status": "Contreadmiral",
#       "description": ""
#     },
#     {
#       "name": "Louise",
#       "gender": "F",
#       "status": "hans Kone",
#       "description": ""
#     },
#     {
#       "name": "Hector Ballandard",
#       "gender": "M",
#       "status": "Prokurator",
#       "description": ""
#     },
#     {
#       "name": "Oliver",
#       "gender": "M",
#       "status": "Emmeries Tjener",
#       "description": ""
#     },
#     {
#       "name": "En Tjener",
#       "gender": "M",
#       "status": "hos Greven",
#       "description": ""
#     },
#     {
#       "name": "En Tjener",
#       "gender": "M",
#       "status": "hos Clerambeau",
#       "description": ""
#     },
#     {
#       "name": "En Notarius",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Tjenere",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1587693.txt",
#   "character_count": 11,
#   "gender_distribution": {
#     "M": 9,
#     "F": 2
#   }
# }
# Added to all_plays: stage_1587693 with 11 characters
#
# Processed stage_1581515.txt:
# Found 12 characters
# Play info: {
#   "title": "stage_1581515",
#   "characters": [
#     {
#       "name": "Greve af Sainville",
#       "gender": "M",
#       "status": "Greve (Count)",
#       "description": ""
#     },
#     {
#       "name": "Armand",
#       "gender": "M",
#       "status": "",
#       "description": ""
#     },
#     {
#       "name": "Madame af Moncerian",
#       "gender": "F",
#       "status": "Marquise",
#       "description": "hans Søster"
#     },
#     {
#       "name": "Charles",
#       "gender": "M",
#       "status": "",
#       "description": "hendes Søn"
#     },
#     {
#       "name": "Rose af Sainville",
#       "gender": "F",
#       "status": "",
#       "description": "Armands Tante"
#     },
#     {
#       "name": "Madame Berten",
#       "gender": "F",
#       "status": "Forstanderende for en Opdragelsesanstalt",
#       "description": ""
#     },
#     {
#       "name": "Piere Chevalier",
#       "gender": "M",
#       "status": "Lærer",
#       "description": ""
#     },
#     {
#       "name": "Levne Montalien",
#       "gender": "F",
#       "status": "Lærerinde",
#       "description": ""
#     },
#     {
#       "name": "Adele",
#       "gender": "F",
#       "status": "Kammerpige hos Margrisen",
#       "description": ""
#     },
#     {
#       "name": "Jannette",
#       "gender": "F",
#       "status": "Pige hos Berlin",
#       "description": ""
#     },
#     {
#       "name": "Andre",
#       "gender": "M",
#       "status": "Gartner",
#       "description": ""
#     },
#     {
#       "name": "Jean",
#       "gender": "M",
#       "status": "en gammel Tjener, hos Greven",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1581515.txt",
#   "character_count": 12,
#   "gender_distribution": {
#     "M": 6,
#     "F": 6
#   }
# }
# Added to all_plays: stage_1581515 with 12 characters
#
# Processed stage_1563988.txt:
# Found 14 characters
# Play info: {
#   "title": "stage_1563988",
#   "characters": [
#     {
#       "name": "Enkedronningen",
#       "gender": "F",
#       "status": "Queen Dowager",
#       "description": ""
#     },
#     {
#       "name": "BortrampoGrav",
#       "gender": "M",
#       "status": "Sonnenberg. Medlem af Conseillet",
#       "description": ""
#     },
#     {
#       "name": "Falkenskjold",
#       "gender": "M",
#       "status": "Krigsminister Medlem af",
#       "description": ""
#     },
#     {
#       "name": "Baron F. v: Goether",
#       "gender": "M",
#       "status": "Neven til Mariniminist",
#       "description": ""
#     },
#     {
#       "name": "Chrstine",
#       "gender": "F",
#       "status": "Falkenskjolds Datter",
#       "description": ""
#     },
#     {
#       "name": "Roller",
#       "gender": "M",
#       "status": "Oberst i Raton",
#       "description": ""
#     },
#     {
#       "name": "Buskenstaf",
#       "gender": "M",
#       "status": "Silke og Klædekræmmer",
#       "description": ""
#     },
#     {
#       "name": "Marthe",
#       "gender": "F",
#       "status": "hans Kone",
#       "description": ""
#     },
#     {
#       "name": "Ludvig",
#       "gender": "M",
#       "status": "hans Søn",
#       "description": ""
#     },
#     {
#       "name": "Johan",
#       "gender": "M",
#       "status": "hans Bontignedring",
#       "description": ""
#     },
#     {
#       "name": "Joseph",
#       "gender": "M",
#       "status": "Falkenskjolds Tjener",
#       "description": ""
#     },
#     {
#       "name": "Berg",
#       "gender": "M",
#       "status": "ham en Hofmand",
#       "description": ""
#     },
#     {
#       "name": "Præsidenten",
#       "gender": "M",
#       "status": "i høieste Ret",
#       "description": ""
#     },
#     {
#       "name": "En Lagna",
#       "gender": "F",
#       "status": "",
#       "description": ""
#     }
#   ],
#   "filepath": "plays/stage_1563988.txt",
#   "character_count": 14,
#   "gender_distribution": {
#     "M": 10,
#     "F": 4
#   }
# }
# Added to all_plays: stage_1563988 with 14 characters
#
# Final data summary:
# Total plays processed: 55
# Plays with characters: 55
#
# Prosessert 55 skuespill

# %%
for play in plays_data:
    print(f"\n{play['title']}:")
    print(f"- Antall karakterer: {len(play['characters'])}")
    print(f"- Karakterer: {', '.join(play['characters'])}")
# Out:
# stage_3971483:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3970963:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971267:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1579397:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1564003:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594278:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1579385:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1563964:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1587674:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971124:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1558153:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594283:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971323:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1579380:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1580805:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594268:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971763:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581439:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1558140:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1582084:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1564166:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594274:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581433:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594281:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1616602:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581578:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594263:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1587724:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971423:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1579379:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971123:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971543:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971212:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971005:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581443:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1558161:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1580777:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3970965:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1587758:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1587740:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1558175:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1558169:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1594255:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3970984:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1564270:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1580816:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1564190:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971765:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581567:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581843:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1564183:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_3971505:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1587693:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1581515:
# - Antall karakterer: 0
# - Karakterer:
#
# stage_1563988:
# - Antall karakterer: 0
# - Karakterer:

# %%
import pandas as pd

# %%
plays_data
# Out:
# [{'title': 'stage_3971483',
#   'characters': [],
#   'filepath': 'plays/stage_3971483.txt',
#   'character_count': 0},
#  {'title': 'stage_3970963',
#   'characters': [],
#   'filepath': 'plays/stage_3970963.txt',
#   'character_count': 0},
#  {'title': 'stage_3971267',
#   'characters': [],
#   'filepath': 'plays/stage_3971267.txt',
#   'character_count': 0},
#  {'title': 'stage_1579397',
#   'characters': [],
#   'filepath': 'plays/stage_1579397.txt',
#   'character_count': 0},
#  {'title': 'stage_1564003',
#   'characters': [],
#   'filepath': 'plays/stage_1564003.txt',
#   'character_count': 0},
#  {'title': 'stage_1594278',
#   'characters': [],
#   'filepath': 'plays/stage_1594278.txt',
#   'character_count': 0},
#  {'title': 'stage_1579385',
#   'characters': [],
#   'filepath': 'plays/stage_1579385.txt',
#   'character_count': 0},
#  {'title': 'stage_1563964',
#   'characters': [],
#   'filepath': 'plays/stage_1563964.txt',
#   'character_count': 0},
#  {'title': 'stage_1587674',
#   'characters': [],
#   'filepath': 'plays/stage_1587674.txt',
#   'character_count': 0},
#  {'title': 'stage_3971124',
#   'characters': [],
#   'filepath': 'plays/stage_3971124.txt',
#   'character_count': 0},
#  {'title': 'stage_1558153',
#   'characters': [],
#   'filepath': 'plays/stage_1558153.txt',
#   'character_count': 0},
#  {'title': 'stage_1594283',
#   'characters': [],
#   'filepath': 'plays/stage_1594283.txt',
#   'character_count': 0},
#  {'title': 'stage_3971323',
#   'characters': [],
#   'filepath': 'plays/stage_3971323.txt',
#   'character_count': 0},
#  {'title': 'stage_1579380',
#   'characters': [],
#   'filepath': 'plays/stage_1579380.txt',
#   'character_count': 0},
#  {'title': 'stage_1580805',
#   'characters': [],
#   'filepath': 'plays/stage_1580805.txt',
#   'character_count': 0},
#  {'title': 'stage_1594268',
#   'characters': [],
#   'filepath': 'plays/stage_1594268.txt',
#   'character_count': 0},
#  {'title': 'stage_3971763',
#   'characters': [],
#   'filepath': 'plays/stage_3971763.txt',
#   'character_count': 0},
#  {'title': 'stage_1581439',
#   'characters': [],
#   'filepath': 'plays/stage_1581439.txt',
#   'character_count': 0},
#  {'title': 'stage_1558140',
#   'characters': [],
#   'filepath': 'plays/stage_1558140.txt',
#   'character_count': 0},
#  {'title': 'stage_1582084',
#   'characters': [],
#   'filepath': 'plays/stage_1582084.txt',
#   'character_count': 0},
#  {'title': 'stage_1564166',
#   'characters': [],
#   'filepath': 'plays/stage_1564166.txt',
#   'character_count': 0},
#  {'title': 'stage_1594274',
#   'characters': [],
#   'filepath': 'plays/stage_1594274.txt',
#   'character_count': 0},
#  {'title': 'stage_1581433',
#   'characters': [],
#   'filepath': 'plays/stage_1581433.txt',
#   'character_count': 0},
#  {'title': 'stage_1594281',
#   'characters': [],
#   'filepath': 'plays/stage_1594281.txt',
#   'character_count': 0},
#  {'title': 'stage_1616602',
#   'characters': [],
#   'filepath': 'plays/stage_1616602.txt',
#   'character_count': 0},
#  {'title': 'stage_1581578',
#   'characters': [],
#   'filepath': 'plays/stage_1581578.txt',
#   'character_count': 0},
#  {'title': 'stage_1594263',
#   'characters': [],
#   'filepath': 'plays/stage_1594263.txt',
#   'character_count': 0},
#  {'title': 'stage_1587724',
#   'characters': [],
#   'filepath': 'plays/stage_1587724.txt',
#   'character_count': 0},
#  {'title': 'stage_3971423',
#   'characters': [],
#   'filepath': 'plays/stage_3971423.txt',
#   'character_count': 0},
#  {'title': 'stage_1579379',
#   'characters': [],
#   'filepath': 'plays/stage_1579379.txt',
#   'character_count': 0},
#  {'title': 'stage_3971123',
#   'characters': [],
#   'filepath': 'plays/stage_3971123.txt',
#   'character_count': 0},
#  {'title': 'stage_3971543',
#   'characters': [],
#   'filepath': 'plays/stage_3971543.txt',
#   'character_count': 0},
#  {'title': 'stage_3971212',
#   'characters': [],
#   'filepath': 'plays/stage_3971212.txt',
#   'character_count': 0},
#  {'title': 'stage_3971005',
#   'characters': [],
#   'filepath': 'plays/stage_3971005.txt',
#   'character_count': 0},
#  {'title': 'stage_1581443',
#   'characters': [],
#   'filepath': 'plays/stage_1581443.txt',
#   'character_count': 0},
#  {'title': 'stage_1558161',
#   'characters': [],
#   'filepath': 'plays/stage_1558161.txt',
#   'character_count': 0},
#  {'title': 'stage_1580777',
#   'characters': [],
#   'filepath': 'plays/stage_1580777.txt',
#   'character_count': 0},
#  {'title': 'stage_3970965',
#   'characters': [],
#   'filepath': 'plays/stage_3970965.txt',
#   'character_count': 0},
#  {'title': 'stage_1587758',
#   'characters': [],
#   'filepath': 'plays/stage_1587758.txt',
#   'character_count': 0},
#  {'title': 'stage_1587740',
#   'characters': [],
#   'filepath': 'plays/stage_1587740.txt',
#   'character_count': 0},
#  {'title': 'stage_1558175',
#   'characters': [],
#   'filepath': 'plays/stage_1558175.txt',
#   'character_count': 0},
#  {'title': 'stage_1558169',
#   'characters': [],
#   'filepath': 'plays/stage_1558169.txt',
#   'character_count': 0},
#  {'title': 'stage_1594255',
#   'characters': [],
#   'filepath': 'plays/stage_1594255.txt',
#   'character_count': 0},
#  {'title': 'stage_3970984',
#   'characters': [],
#   'filepath': 'plays/stage_3970984.txt',
#   'character_count': 0},
#  {'title': 'stage_1564270',
#   'characters': [],
#   'filepath': 'plays/stage_1564270.txt',
#   'character_count': 0},
#  {'title': 'stage_1580816',
#   'characters': [],
#   'filepath': 'plays/stage_1580816.txt',
#   'character_count': 0},
#  {'title': 'stage_1564190',
#   'characters': [],
#   'filepath': 'plays/stage_1564190.txt',
#   'character_count': 0},
#  {'title': 'stage_3971765',
#   'characters': [],
#   'filepath': 'plays/stage_3971765.txt',
#   'character_count': 0},
#  {'title': 'stage_1581567',
#   'characters': [],
#   'filepath': 'plays/stage_1581567.txt',
#   'character_count': 0},
#  {'title': 'stage_1581843',
#   'characters': [],
#   'filepath': 'plays/stage_1581843.txt',
#   'character_count': 0},
#  {'title': 'stage_1564183',
#   'characters': [],
#   'filepath': 'plays/stage_1564183.txt',
#   'character_count': 0},
#  {'title': 'stage_3971505',
#   'characters': [],
#   'filepath': 'plays/stage_3971505.txt',
#   'character_count': 0},
#  {'title': 'stage_1587693',
#   'characters': [],
#   'filepath': 'plays/stage_1587693.txt',
#   'character_count': 0},
#  {'title': 'stage_1581515',
#   'characters': [],
#   'filepath': 'plays/stage_1581515.txt',
#   'character_count': 0},
#  {'title': 'stage_1563988',
#   'characters': [],
#   'filepath': 'plays/stage_1563988.txt',
#   'character_count': 0}]
