# %%
import os
import pandas as pd
api_key = os.getenv("ANTHROPIC_API_KEY")

# %%
import anthropic
from pathlib import Path
import json
from typing import Dict, List
import logging
from time import sleep

class PlayMetadataProcessor:
    def __init__(self, api_key: str, plays_directory: str):
        self.client = anthropic.Client(api_key=api_key)
        self.plays_dir = Path(plays_directory)
        
    def extract_metadata(self, text: str, play_title: str) -> Dict:
        prompt = f"""Analyze the beginning of this Norwegian/Danish play from the 1800s and extract the following metadata if present:
        - Year (look for years between 1750-1900)
        - Title of the play
        - Number of acts (look for "Acter", "Akt", etc.)
        - Author name
        - Genre (look for terms like: Lystspil, Drama, Sørgespil, Vaudeville, Syngestykke, Comoedie, Tragoedie)
        
        Return ONLY a Python dictionary with these keys: {{"year": null or int, "title": str or null, "acts": int or null, "author": str or null, "genre": str or null}}
        If information isn't found, use null.
        
        Example responses:
        {{"year": 1842, "title": "Den Unge Gudmoder", "acts": 3, "author": "P.A. Heiberg", "genre": "Lystspil"}}
        {{"year": 1835, "title": "Formynder og Myndling", "acts": 5, "author": "Scribe", "genre": "Syngestykke"}}

        Text to analyze:
        {text}"""
        
        try:
            response = self.client.messages.create(
                model="claude-3-sonnet-20240229",
                max_tokens=1000,
                temperature=0,
                messages=[{"role": "user", "content": prompt}]
            )
            
            raw_response = response.content[0].text.strip()
            print(f"\nProcessing: {play_title}")
            print("Raw LLM response:")
            print(raw_response)
            
            # Find and parse the dictionary
            start_idx = raw_response.find('{')
            end_idx = raw_response.rfind('}') + 1
            if start_idx != -1 and end_idx != -1:
                dict_str = raw_response[start_idx:end_idx]
                try:
                    metadata = json.loads(dict_str)
                    return metadata
                except:
                    print(f"Failed to parse metadata for {play_title}")
                    return {"year": None, "title": None, "acts": None, "author": None, "genre": None}
            return {"year": None, "title": None, "acts": None, "author": None, "genre": None}
            
        except Exception as e:
            print(f"Error processing {play_title}: {str(e)}")
            return {"year": None, "title": None, "acts": None, "author": None, "genre": None}
    
    def process_play(self, filepath: Path) -> Dict:
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                play_start = f.read(1000)  # First 1000 characters should contain metadata
            
            metadata = self.extract_metadata(play_start, filepath.stem)
            
            play_info = {
                'filename': filepath.stem,
                'filepath': str(filepath),
                **metadata
            }
            
            print(f"Extracted metadata from {filepath.name}")
            return play_info
            
        except Exception as e:
            print(f"Error reading {filepath}: {str(e)}")
            return {
                'filename': filepath.stem,
                'filepath': str(filepath),
                'year': None,
                'title': None,
                'acts': None,
                'author': None,
                'genre': None
            }

    def process_all_plays(self, delay: float = 1.0) -> List[Dict]:
        play_files = list(self.plays_dir.glob('*.txt'))
        all_plays = []
        
        print(f"Found {len(play_files)} plays to process")
        
        for play_file in play_files:
            play_info = self.process_play(play_file)
            all_plays.append(play_info)
            
            # Save after each play is processed
            output_file = self.plays_dir / 'plays_metadata.json'
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(all_plays, f, indent=2, ensure_ascii=False)
            
            sleep(delay)
                
        return all_plays

# %%
processor = PlayMetadataProcessor(api_key, "./plays")
metadata = processor.process_all_plays()
# Out:
# Found 55 plays to process
#
# Processing: stage_3971483
# Raw LLM response:
# {
#     "year": 1778,
#     "title": "Til Sæters",
#     "acts": null,
#     "author": "E. S. Res.",
#     "genre": "Dramatisk Idel med Sange"
# }
# Extracted metadata from stage_3971483.txt
#
# Processing: stage_3970963
# Raw LLM response:
# {
#     "year": null,
#     "title": "Rosa og Rosita",
#     "acts": 2,
#     "author": null,
#     "genre": "Lystspil"
# }
# Extracted metadata from stage_3970963.txt
#
# Processing: stage_3971267
# Raw LLM response:
# Basert på teksten gir jeg følgende metadata:
#
# {"year": 1851, "title": "Scheik Hassan", "acts": 3, "author": "Henrik Hertz", "genre": "Lystspil"}
# Extracted metadata from stage_3971267.txt
#
# Processing: stage_1579397
# Raw LLM response:
# Basert på den gitte teksten, er den ekstraherte metadata:
#
# {"year": null, "title": "Batailles des dames", "acts": 5, "author": "Scribe og Legeme", "genre": "Lystspil"}
#
# Forklaringer:
# - Ingen årstall mellom 1750-1900 er oppgitt, så "year" er null.
# - Tittelen "Batailles des dames" er oppgitt.
# - Det står "Lystspil i 5 Akter", så antall akter er 5.
# - Forfatterne er oppgitt som "Scribe og Legeme".
# - Sjangeren er oppgitt som "Lystspil".
# Extracted metadata from stage_1579397.txt
#
# Processing: stage_1564003
# Raw LLM response:
# {"year": 1832, "title": "Den skjønneste Dagi Livet", "acts": 2, "author": "Johan Ludvig Heiberg", "genre": "Vaudeville"}
# Extracted metadata from stage_1564003.txt
#
# Processing: stage_1594278
# Raw LLM response:
# {
# "year": null,
# "title": "Han er af god Familie",
# "acts": 3,
# "author": null,
# "genre": "Comedie"
# }
# Extracted metadata from stage_1594278.txt
#
# Processing: stage_1579385
# Raw LLM response:
# Basert på teksten ser det ut som følgende metadata kan utledes:
#
# {
#     "year": null,
#     "title": "Pariserdringen",
#     "acts": 2,
#     "author": "Bayrde Vanderbarn",
#     "genre": "Lystspil"
# }
#
# Noen kommentarer:
#
# - Ingen årstall mellom 1750-1900 er oppgitt, så "year" er null.
# - Tittelen "Pariserdringen" er oppgitt som et "nyt Lystspil i 2 Akter".
# - Antall akter er 2.
# - Forfatteren er oppgitt som "Bayrde Vanderbarn".
# - Sjangeren er oppgitt som "Lystspil".
# Extracted metadata from stage_1579385.txt
#
# Processing: stage_1563964
# Raw LLM response:
# Here is the extracted metadata in a Python dictionary:
#
# {
#     "year": None,
#     "title": None,
#     "acts": 1,
#     "author": None,
#     "genre": None
# }
#
# Explanation:
# - No year is explicitly stated in the given text excerpt.
# - No title is given for the play.
# - The text mentions "Første Act" which indicates there is at least 1 act.
# - No author name is provided.
# - No genre terms like Lystspil, Drama, etc. are used to identify the genre.
# Failed to parse metadata for stage_1563964
# Extracted metadata from stage_1563964.txt
#
# Processing: stage_1587674
# Raw LLM response:
# {
#     "year": null,
#     "title": "Keiserendens Fanger",
#     "acts": 2,
#     "author": "Bayar",
#     "genre": "Lystspil"
# }
# Extracted metadata from stage_1587674.txt
#
# Processing: stage_3971124
# Raw LLM response:
# {"year": 1862, "title": "Brødrene", "acts": 3, "author": "H. Olaf Hansen", "genre": "Skuespil"}
# Extracted metadata from stage_3971124.txt
#
# Processing: stage_1558153
# Raw LLM response:
# Basert på teksten ser det ut som følgende metadata:
#
# {"year": null, "title": "Den unge Gudmoder", "acts": 1, "author": "Serike, Loekrog og Chabot de Bonen", "genre": "Vaudeville"}
#
# Noen kommentarer:
#
# - Ingen årstall mellom 1750-1900 er oppgitt, så year er null
# - Tittelen "Den unge Gudmoder" er oppgitt
# - Det står "Vaudeville i 1 Act", så antall akter er 1
# - Forfatterne er oppgitt som "Serike, Loekrog og Chabot de Bonen"
# - Sjangeren er oppgitt som "Vaudeville"
# Extracted metadata from stage_1558153.txt
#
# Processing: stage_1594283
# Raw LLM response:
# {"year": null, "title": null, "acts": null, "author": null, "genre": null}
# Extracted metadata from stage_1594283.txt
#
# Processing: stage_3971323
# Raw LLM response:
# {
# "year": 1852,
# "title": "Huldrens Hjem",
# "acts": null,
# "author": "P. A. Jensen",
# "genre": "Dramatisk Digtning"
# }
# Extracted metadata from stage_3971323.txt
#
# Processing: stage_1579380
# Raw LLM response:
# {
#     "year": null,
#     "title": null,
#     "acts": null,
#     "author": null,
#     "genre": "Sørgespil, Comoedie, Syngestykke, Lystspil, Tragoedie, Vaudeville"
# }
# Extracted metadata from stage_1579380.txt
#
# Processing: stage_1580805
# Raw LLM response:
# {"year": 1750, "title": "Handsken og Viften", "acts": 3, "author": null, "genre": "Comedie"}
# Extracted metadata from stage_1580805.txt
#
# Processing: stage_1594268
# Raw LLM response:
# {"year": null, "title": "Ovækeren og Dandserinden", "acts": 1, "author": "J. L. Heiberg", "genre": "Lystspil"}
# Extracted metadata from stage_1594268.txt
#
# Processing: stage_3971763
# Raw LLM response:
# Basert på teksten ser det ut som følgende metadata kan utledes:
#
# {
# "year": null,
# "title": "Tordenskjold",
# "acts": 1,
# "author": "H. G. Blom",
# "genre": "Vaudeville"
# }
#
# Begrunnelser:
# - Ingen årstall mellom 1750-1900 er oppgitt, så year er null
# - Tittelen "Tordenskjold Vaudeville i een Act" er oppgitt
# - "een Act" indikerer at det er 1 akt
# - Forfatteren "H. G. Blom" er oppgitt
# - Sjangeren "Vaudeville" er oppgitt
# Extracted metadata from stage_3971763.txt
#
# Processing: stage_1581439
# Raw LLM response:
# {"year": 1827, "title": "Kjærligheds Dromme", "acts": null, "author": "Johan Ludvig Heiberg", "genre": "Vaudeville"}
# Extracted metadata from stage_1581439.txt
#
# Processing: stage_1558140
# Raw LLM response:
# Here is the dictionary with the extracted metadata:
#
# {
#     "year": 1896,
#     "title": "Den unge Gudmoder",
#     "acts": null,
#     "author": null,
#     "genre": "Vaudeville"
# }
#
# Explanation:
# - The year 1896 is clearly stated at the beginning.
# - The title "Den unge Gudmoder" is listed.
# - I could not find any mention of the number of acts.
# - There is no author name listed.
# - The genre is listed as "Vaudeville" (the Danish spelling "Vandevelle" is used).
# Extracted metadata from stage_1558140.txt
#
# Processing: stage_1582084
# Raw LLM response:
# {"year": null, "title": "Adrienne Lecouvreur", "acts": 5, "author": null, "genre": "Drama"}
# Extracted metadata from stage_1582084.txt
#
# Processing: stage_1564166
# Raw LLM response:
# {"year": null, "title": "Chevalier de Grignon", "acts": 2, "author": "Bagard og Milesville", "genre": "Comedie"}
# Extracted metadata from stage_1564166.txt
#
# Processing: stage_1594274
# Raw LLM response:
# Basert på teksten kan jeg utlede følgende metadata:
#
# {"year": 1855, "title": "En Heks", "acts": 5, "author": "Charlotte Birch-Pfeiffer", "genre": "Skuespil"}
#
# Årstallet 1855 er ikke eksplisitt nevnt, men stykket er fra 1800-tallet basert på tittelen "En Heks" og forfatternavnet Charlotte Birch-Pfeiffer. Antall akter er oppgitt til 5, og sjangeren er "Skuespil" som tilsvarer drama/skuespill.
# Extracted metadata from stage_1594274.txt
#
# Processing: stage_1581433
# Raw LLM response:
# {
#     "year": null,
#     "title": "Landsbye og Skuespil",
#     "acts": 5,
#     "author": null,
#     "genre": "Skuespil"
# }
# Extracted metadata from stage_1581433.txt
#
# Processing: stage_1594281
# Raw LLM response:
# {
#     "year": null,
#     "title": "Gamle Minder",
#     "acts": null,
#     "author": null,
#     "genre": "Comedie med Sange"
# }
# Extracted metadata from stage_1594281.txt
#
# Processing: stage_1616602
# Raw LLM response:
# {"year": null, "title": null, "acts": null, "author": null, "genre": "Sørgespil, Comoedie, Syngestykke, Lystspil, Tragoedie, Vaudeville"}
# Extracted metadata from stage_1616602.txt
#
# Processing: stage_1581578
# Raw LLM response:
# {
# "year": null,
# "title": "Lazarilla",
# "acts": 1,
# "author": null,
# "genre": "Syngespil"
# }
# Extracted metadata from stage_1581578.txt
#
# Processing: stage_1594263
# Raw LLM response:
# Basert på teksten ser det ut som følgende metadata kan utledes:
#
# {"year": 1842, "title": "Hun skal debutere", "acts": 5, "author": "Erik Bøgh", "genre": "Farce med Sang"}
# Extracted metadata from stage_1594263.txt
#
# Processing: stage_1587724
# Raw LLM response:
# {"year": null, "title": "Et Glas Vand", "acts": 5, "author": "Engene Siribe", "genre": "Komedie"}
# Extracted metadata from stage_1587724.txt
#
# Processing: stage_3971423
# Raw LLM response:
# Basert på teksten ser det ut som følgende metadata:
#
# {"year": null, "title": "Donna Clara", "acts": null, "author": null, "genre": null}
#
# Grunnen er:
# - Ingen årstall mellom 1750-1900 er oppgitt
# - Tittelen "Donna Clara" er nevnt
# - Ingen informasjon om antall akter
# - Ingen forfatter er nevnt
# - Ingen sjanger som lystspill, drama etc. er oppgitt
#
# Så dessverre mangler en del metadata i denne teksten. Tittelen er det eneste som kommer tydelig frem.
# Extracted metadata from stage_3971423.txt
#
# Processing: stage_1579379
# Raw LLM response:
# Basert på den gitte teksten ser det ikke ut til at det er nok informasjon til å fylle ut alle feltene i det ønskede dictionary-formatet. Her er et forsøk:
#
# {"year": null, "title": null, "acts": null, "author": null, "genre": "Sørgespil"}
#
# Teksten ser ut til å være en liste over forestillinger på Det Kongelige Teater, men inneholder lite metadata om de individuelle stykkene utover at "Emilie Galotti" er et "Sørgespil af Lessing". Ingen årstall, antall akter eller fullstendige titler er oppgitt.
# Extracted metadata from stage_1579379.txt
#
# Processing: stage_3971123
# Raw LLM response:
# {"year": 1855, "title": "En Aften paa Giske", "acts": 1, "author": "A. Munch", "genre": "historisk Skuespil"}
# Extracted metadata from stage_3971123.txt
#
# Processing: stage_3971543
# Raw LLM response:
# {"year": 1864, "title": "Ole Høiland", "acts": 1, "author": "T. Marius Peterson", "genre": "Lystspil"}
# Extracted metadata from stage_3971543.txt
#
# Processing: stage_3971212
# Raw LLM response:
# {"year": 1860, "title": "En ung Piges Roman", "acts": 5, "author": null, "genre": "Lystspil med Sange"}
# Extracted metadata from stage_3971212.txt
#
# Processing: stage_3971005
# Raw LLM response:
# Basert på teksten du ga meg, er dette metadataen jeg kan utlede:
#
# {"year": 1857, "title": "Gudbrandsdølerne", "acts": 4, "author": "Chr. Monsen", "genre": "Drama"}
#
# Forklaringer:
# - Året 1857 er oppgitt to ganger i teksten.
# - Tittelen "Gudbrandsdølerne" er oppgitt.
# - Det står "Drama i fire Handlinger", så det er 4 akter/handlinger.
# - Forfatteren er oppgitt som "Chr. Monsen".
# - Sjangeren er ikke eksplisitt oppgitt, men siden det har flere akter/handlinger antar jeg det er et skuespill/drama.
# Extracted metadata from stage_3971005.txt
#
# Processing: stage_1581443
# Raw LLM response:
# Her er den ønskede metadata i et Python-dictionary:
#
# {
#     "year": None,
#     "title": "Kostgængeren",
#     "acts": 1,
#     "author": "Scribe",
#     "genre": "Lystspil"
# }
#
# Bemærkninger:
# - Ingen årstal er angivet i teksten, så "year" er sat til None.
# - Tittelen "Kostgængeren" er angivet.
# - Det angives at det er et "Lystspil i een Act", så "acts" er sat til 1.
# - Forfatteren angives som "Scribe".
# - Genren angives som "Lystspil".
# Failed to parse metadata for stage_1581443
# Extracted metadata from stage_1581443.txt
#
# Processing: stage_1558161
# Raw LLM response:
# {
#     "year": null,
#     "title": null,
#     "acts": null,
#     "author": null,
#     "genre": null
# }
# Extracted metadata from stage_1558161.txt
#
# Processing: stage_1580777
# Raw LLM response:
# Here is the dictionary with the extracted metadata:
#
# {
#     "year": 1835,
#     "title": "Fra Diavolo",
#     "acts": 3,
#     "author": "Scribe",
#     "genre": "Syngespil"
# }
#
# Notes:
# - The year 1835 is not explicitly stated but can be inferred from the publication details "N. 104 Seflorbog til Fra Diavolo ark 2. 305. 108"
# - The title "Fra Diavolo eller Terracina i Værtshuset" is listed
# - It states "Syngespil i 3 Acter" indicating 3 acts
# - The author is listed as "Scribe"
# - The genre is listed as "Syngespil" which means a musical play
# Extracted metadata from stage_1580777.txt
#
# Processing: stage_3970965
# Raw LLM response:
# {"year": 1853, "title": "Anna Kolbjørnsdatter", "acts": 3, "author": "Rolf Olsen", "genre": "Skuespil"}
# Extracted metadata from stage_3970965.txt
#
# Processing: stage_1587758
# Raw LLM response:
# {"year": null, "title": "Min Stjerne", "acts": 1, "author": "H. Scribe", "genre": "Lystspil"}
# Extracted metadata from stage_1587758.txt
#
# Processing: stage_1587740
# Raw LLM response:
# {"year": null, "title": "Embedsiver eller Hr. og Fru Møller", "acts": 3, "author": null, "genre": "Lystspil"}
# Extracted metadata from stage_1587740.txt
#
# Processing: stage_1558175
# Raw LLM response:
# {"year": null, "title": "Enten elskes eller døe!", "acts": 1, "author": "Scribe", "genre": "Lystspil"}
# Extracted metadata from stage_1558175.txt
#
# Processing: stage_1558169
# Raw LLM response:
# {
#     "year": 1891,
#     "title": null,
#     "acts": 5,
#     "author": "gribe",
#     "genre": "Comedie"
# }
# Extracted metadata from stage_1558169.txt
#
# Processing: stage_1594255
# Raw LLM response:
# {"year": null, "title": null, "acts": null, "author": null, "genre": null}
# Extracted metadata from stage_1594255.txt
#
# Processing: stage_3970984
# Raw LLM response:
# {"year": 1855, "title": "Slægtningerne", "acts": 1, "author": null, "genre": "Vaudeville"}
# Extracted metadata from stage_3970984.txt
#
# Processing: stage_1564270
# Raw LLM response:
# {
#     "year": null,
#     "title": "Ægtemanden paa Landet",
#     "acts": 3,
#     "author": "G. E. Schjelderup",
#     "genre": "Comedie"
# }
# Extracted metadata from stage_1564270.txt
#
# Processing: stage_1580816
# Raw LLM response:
# {"year": 1800, "title": null, "acts": 2, "author": null, "genre": null}
# Extracted metadata from stage_1580816.txt
#
# Processing: stage_1564190
# Raw LLM response:
# {"year": 1836, "title": "Trylleopera i tre Acter", "acts": 3, "author": null, "genre": "Trylleopera"}
# Extracted metadata from stage_1564190.txt
#
# Processing: stage_3971765
# Raw LLM response:
# {"year": 1837, "title": "Et ungt Ægtepars Huusholdning", "acts": 4, "author": null, "genre": null}
# Extracted metadata from stage_3971765.txt
#
# Processing: stage_1581567
# Raw LLM response:
# {
#     "year": 1899,
#     "title": "Tullivan",
#     "acts": 3,
#     "author": null,
#     "genre": "Comedie"
# }
# Extracted metadata from stage_1581567.txt
#
# Processing: stage_1581843
# Raw LLM response:
# {
#     "year": 1892,
#     "title": "Den laante Elsker",
#     "acts": 1,
#     "author": "Scribe og Mélesville",
#     "genre": "Vaudeville"
# }
# Extracted metadata from stage_1581843.txt
#
# Processing: stage_1564183
# Raw LLM response:
# {
#     "year": null,
#     "title": null,
#     "acts": null,
#     "author": null,
#     "genre": null
# }
# Extracted metadata from stage_1564183.txt
#
# Processing: stage_3971505
# Raw LLM response:
# {
#     "year": null,
#     "title": "Advokatens Datter",
#     "acts": 2,
#     "author": "Mad. Ancelot",
#     "genre": "Drama"
# }
# Extracted metadata from stage_3971505.txt
#
# Processing: stage_1587693
# Raw LLM response:
# {"year": null, "title": "En Lænke", "acts": 4, "author": "Eugène Scribe", "genre": "Komedie"}
# Extracted metadata from stage_1587693.txt
#
# Processing: stage_1581515
# Raw LLM response:
# {"year": null, "title": "Sydens Datter", "acts": 5, "author": "Charlotte Birch-Pfeiffer", "genre": null}
# Extracted metadata from stage_1581515.txt
#
# Processing: stage_1563988
# Raw LLM response:
# Here is the dictionary with the extracted metadata:
#
# {
#     "year": 1772,
#     "title": "Bestand og Rator eller Kunsten at smidde en damen sværgelse",
#     "acts": 5,
#     "author": "Engene deribe",
#     "genre": "Comedie"
# }
# Extracted metadata from stage_1563988.txt

# %%
# Quick analysis while it's running or after completion
df_metadata = pd.DataFrame(metadata)

# Check which fields we're successfully extracting
print("\nSuccessful extractions per field:")
print(df_metadata.notna().sum())

# For years found
if df_metadata['year'].notna().any():
    print("\nYears found:")
    print(df_metadata[df_metadata['year'].notna()][['filename', 'year', 'title']].head())

# For acts found
if df_metadata['acts'].notna().any():
    print("\nNumber of acts found:")
    print(df_metadata[df_metadata['acts'].notna()][['filename', 'acts', 'title']].head())

# For plays with authors
if df_metadata['author'].notna().any():
    print("\nAuthors found:")
    print(df_metadata[df_metadata['author'].notna()][['filename', 'author', 'title']].head())
# Out:
# Successful extractions per field:
# filename    55
# filepath    55
# year        24
# title       44
# acts        40
# author      30
# genre       45
# dtype: int64
#
# Years found:
#          filename    year                      title
# 0   stage_3971483  1778.0                 Til Sæters
# 2   stage_3971267  1851.0              Scheik Hassan
# 4   stage_1564003  1832.0  Den skjønneste Dagi Livet
# 9   stage_3971124  1862.0                   Brødrene
# 12  stage_3971323  1852.0              Huldrens Hjem
#
# Number of acts found:
#         filename  acts                      title
# 1  stage_3970963   2.0             Rosa og Rosita
# 2  stage_3971267   3.0              Scheik Hassan
# 3  stage_1579397   5.0        Batailles des dames
# 4  stage_1564003   2.0  Den skjønneste Dagi Livet
# 5  stage_1594278   3.0      Han er af god Familie
#
# Authors found:
#         filename                author                      title
# 0  stage_3971483            E. S. Res.                 Til Sæters
# 2  stage_3971267          Henrik Hertz              Scheik Hassan
# 3  stage_1579397      Scribe og Legeme        Batailles des dames
# 4  stage_1564003  Johan Ludvig Heiberg  Den skjønneste Dagi Livet
# 6  stage_1579385     Bayrde Vanderbarn             Pariserdringen

# %%
df_metadata.to_excel("metadata.xlsx")

# %%
pd.DataFrame(metadata)
# Out:
#          filename                 filepath    year  \
# 0   stage_3971483  plays/stage_3971483.txt     NaN
# 1   stage_3970963  plays/stage_3970963.txt     NaN
# 2   stage_3971267  plays/stage_3971267.txt  1851.0
# 3   stage_1579397  plays/stage_1579397.txt     NaN
# 4   stage_1564003  plays/stage_1564003.txt  1832.0
# 5   stage_1594278  plays/stage_1594278.txt     NaN
# 6   stage_1579385  plays/stage_1579385.txt     NaN
# 7   stage_1563964  plays/stage_1563964.txt     NaN
# 8   stage_1587674  plays/stage_1587674.txt     NaN
# 9   stage_3971124  plays/stage_3971124.txt  1862.0
# 10  stage_1558153  plays/stage_1558153.txt     NaN
# 11  stage_1594283  plays/stage_1594283.txt     NaN
# 12  stage_3971323  plays/stage_3971323.txt  1852.0
# 13  stage_1579380  plays/stage_1579380.txt     NaN
# 14  stage_1580805  plays/stage_1580805.txt  1750.0
# 15  stage_1594268  plays/stage_1594268.txt     NaN
# 16  stage_3971763  plays/stage_3971763.txt     NaN
# 17  stage_1581439  plays/stage_1581439.txt  1827.0
# 18  stage_1558140  plays/stage_1558140.txt     NaN
# 19  stage_1582084  plays/stage_1582084.txt     NaN
# 20  stage_1564166  plays/stage_1564166.txt     NaN
# 21  stage_1594274  plays/stage_1594274.txt  1855.0
# 22  stage_1581433  plays/stage_1581433.txt     NaN
# 23  stage_1594281  plays/stage_1594281.txt     NaN
# 24  stage_1616602  plays/stage_1616602.txt     NaN
# 25  stage_1581578  plays/stage_1581578.txt     NaN
# 26  stage_1594263  plays/stage_1594263.txt  1842.0
# 27  stage_1587724  plays/stage_1587724.txt     NaN
# 28  stage_3971423  plays/stage_3971423.txt     NaN
# 29  stage_1579379  plays/stage_1579379.txt     NaN
# 30  stage_3971123  plays/stage_3971123.txt  1855.0
# 31  stage_3971543  plays/stage_3971543.txt  1864.0
# 32  stage_3971212  plays/stage_3971212.txt  1860.0
# 33  stage_3971005  plays/stage_3971005.txt  1857.0
# 34  stage_1581443  plays/stage_1581443.txt     NaN
# 35  stage_1558161  plays/stage_1558161.txt     NaN
# 36  stage_1580777  plays/stage_1580777.txt     NaN
# 37  stage_3970965  plays/stage_3970965.txt  1853.0
# 38  stage_1587758  plays/stage_1587758.txt     NaN
# 39  stage_1587740  plays/stage_1587740.txt     NaN
# 40  stage_1558175  plays/stage_1558175.txt     NaN
# 41  stage_1558169  plays/stage_1558169.txt  1891.0
# 42  stage_1594255  plays/stage_1594255.txt     NaN
# 43  stage_3970984  plays/stage_3970984.txt  1855.0
# 44  stage_1564270  plays/stage_1564270.txt     NaN
# 45  stage_1580816  plays/stage_1580816.txt  1800.0
# 46  stage_1564190  plays/stage_1564190.txt  1836.0
# 47  stage_3971765  plays/stage_3971765.txt  1837.0
# 48  stage_1581567  plays/stage_1581567.txt  1899.0
# 49  stage_1581843  plays/stage_1581843.txt  1892.0
# 50  stage_1564183  plays/stage_1564183.txt     NaN
# 51  stage_3971505  plays/stage_3971505.txt     NaN
# 52  stage_1587693  plays/stage_1587693.txt     NaN
# 53  stage_1581515  plays/stage_1581515.txt     NaN
# 54  stage_1563988  plays/stage_1563988.txt  1772.0
#
#                                                 title  acts  \
# 0                                                None   NaN
# 1                                      Rosa og Rosita   2.0
# 2                                       Scheik Hassan   3.0
# 3                                 Batailles des dames   5.0
# 4                           Den skjønneste Dagi Livet   2.0
# 5                               Hau er af god Familie   3.0
# 6                                      Pariserdringen   2.0
# 7                                                None   1.0
# 8                                 Keiserendens Fanger   2.0
# 9                                            Brødrene   3.0
# 10                                  Den unge Gudmoder   1.0
# 11                                               None   NaN
# 12                                      Huldrens Hjem   NaN
# 13                                               None   NaN
# 14                                 Handsken og Viften   3.0
# 15                           Ovækeren og Dandserinden   1.0
# 16                                       Tordenskjold   1.0
# 17                                 Kjærligheds Dromme   NaN
# 18                                               None   NaN
# 19                                Adrienne Lecouvreur   5.0
# 20                               Chevalier de Grignon   2.0
# 21                                            En Heks   5.0
# 22                                               None   5.0
# 23                                       Gamle Minder   NaN
# 24                                               None   NaN
# 25                                          Lazarilla   1.0
# 26                                          Sufflorbo   5.0
# 27                                       Et Glas Vand   5.0
# 28                                        Donna Clara   NaN
# 29                                               None   NaN
# 30                                 En Aften paa Giske   1.0
# 31                                        Ole Høiland   1.0
# 32                                 En ung Piges Roman   5.0
# 33                                   Gudbrandsdølerne   4.0
# 34                                               None   NaN
# 35                                               None   NaN
# 36                                        Fra Diavolo   3.0
# 37                               Anna Kolbjørnsdatter   3.0
# 38                                        Min Stjerne   1.0
# 39                 Embedsiver eller Hr. og Fru Møller   3.0
# 40                            Enten elskes eller døe!   1.0
# 41                                               None   5.0
# 42                                               None   NaN
# 43                                      Slægtningerne   1.0
# 44                                               None   NaN
# 45                                               None   1.0
# 46                            Trylleopera i tre Acter   3.0
# 47                      Et ungt Ægtepars Huusholdning   NaN
# 48                                               None   3.0
# 49                        Goe eller den laante Elsker   1.0
# 50                                               None   NaN
# 51                                  Advokatens Datter   2.0
# 52                                           En Lænke   4.0
# 53                                      Sydens Datter   5.0
# 54  Bestand og Rator eller Kunsten at smidde en da...   5.0
#
#                                 author
# 0                                 None
# 1                                 None
# 2                         Henrik Hertz
# 3                     Scribe og Legeme
# 4                 Johan Ludvig Heiberg
# 5                                 None
# 6                    Bayrde Vanderbarn
# 7                                 None
# 8                                Bayar
# 9                       H. Olaf Hansen
# 10  Serike, Loekrog og Chabot de Bonen
# 11                        P.A. Heiberg
# 12                         P.A. Jensen
# 13                        P.A. Heiberg
# 14                                None
# 15                                None
# 16                          H. G. Blom
# 17                Johan Ludvig Heiberg
# 18                                None
# 19                                None
# 20                Bagard og Milesville
# 21            Charlotte Birch-Pfeiffer
# 22                                None
# 23                                None
# 24                        P.A. Heiberg
# 25                                None
# 26                           Erik Bøgh
# 27                       Engene Siribe
# 28                       Andreas Munch
# 29                        P.A. Heiberg
# 30                            A. Munch
# 31                  T. Marius Peterson
# 32                                None
# 33                         Chr. Monsen
# 34                                None
# 35                                None
# 36                                None
# 37                          Rolf Olsen
# 38                           H. Scribe
# 39                                None
# 40   Scribe (oversat af J. L. Heiberg)
# 41                                None
# 42                        P.A. Heiberg
# 43                                None
# 44                                None
# 45                                None
# 46                                None
# 47                                None
# 48                                None
# 49                                None
# 50                                None
# 51                        Mad. Ancelot
# 52                       Eugène Scribe
# 53            Charlotte Birch-Pfeiffer
# 54                       Engene deribe
